# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
sns.set()

# %%
zipcode = '97035'
filename = zipcode + '_homes_data_cleaned.csv'
df = pd.read_csv(filename)

# %%
df.describe(include='all')
# Out:
#                       Address  \
# count                     162
# unique                    162
# top     4965 SW Park Bluff Pl
# freq                        1
# mean                      NaN
# std                       NaN
# min                       NaN
# 25%                       NaN
# 50%                       NaN
# 75%                       NaN
# max                       NaN
#
#                                                      link         price  \
# count                                                 162  1.620000e+02
# unique                                                162           NaN
# top     https://www.redfin.com/OR/Lake-Oswego/4965-Par...           NaN
# freq                                                    1           NaN
# mean                                                  NaN  9.283610e+05
# std                                                   NaN  1.177257e+06
# min                                                   NaN  1.500000e+05
# 25%                                                   NaN  3.325000e+05
# 50%                                                   NaN  6.328445e+05
# 75%                                                   NaN  9.497500e+05
# max                                                   NaN  1.050000e+07
#
#               beds       baths         sqft view_yn     yr_built cooling_yn  \
# count   162.000000  162.000000   162.000000     162   162.000000        162
# unique         NaN         NaN          NaN       2          NaN          2
# top            NaN         NaN          NaN     Yes          NaN        Yes
# freq           NaN         NaN          NaN      90          NaN        104
# mean      3.061728    2.391975  2115.493827     NaN  1980.222222        NaN
# std       1.101616    0.988630  1321.639093     NaN    18.294689        NaN
# min       1.000000    1.000000   600.000000     NaN  1920.000000        NaN
# 25%       2.000000    2.000000  1178.500000     NaN  1970.000000        NaN
# 50%       3.000000    2.500000  1742.500000     NaN  1979.000000        NaN
# 75%       4.000000    2.500000  2706.750000     NaN  1988.000000        NaN
# max       6.000000    6.500000  8170.000000     NaN  2023.000000        NaN
#
#        has_hoa senior_community_yn                      style  \
# count      162                 162                        162
# unique       2                   2                          2
# top        Yes                  No  Single Family Residential
# freq        92                 160                        106
# mean       NaN                 NaN                        NaN
# std        NaN                 NaN                        NaN
# min        NaN                 NaN                        NaN
# 25%        NaN                 NaN                        NaN
# 50%        NaN                 NaN                        NaN
# 75%        NaN                 NaN                        NaN
# max        NaN                 NaN                        NaN
#
#                   county new_construction_yn
# count                162                 162
# unique                 2                   2
# top     Clackamas County                  No
# freq                 123                 157
# mean                 NaN                 NaN
# std                  NaN                 NaN
# min                  NaN                 NaN
# 25%                  NaN                 NaN
# 50%                  NaN                 NaN
# 75%                  NaN                 NaN
# max                  NaN                 NaN

# %%
df['log_price'] = np.log(df['price'])

# %%
df.isnull().sum()
# Out:
# Address                0
# link                   0
# price                  0
# beds                   0
# baths                  0
# sqft                   0
# view_yn                0
# yr_built               0
# cooling_yn             0
# has_hoa                0
# senior_community_yn    0
# style                  0
# county                 0
# new_construction_yn    0
# log_price              0
# dtype: int64

# %%
ax=sns.displot(df['log_price'])

# %%
q = df['log_price'].quantile(0.95)
df = df[df['log_price']<q]

# %%
ax=sns.displot(df['beds'])

# %%
ax=sns.displot(df['baths'])

# %%
ax=sns.displot(np.sqrt(df['sqft']))

# %%
df['sqft'] = np.sqrt(df['sqft'])

# %%
ax=sns.displot(df['sqft'])

# %%
ax=sns.displot(df['yr_built'])

# %%
q = df['yr_built'].quantile(0.01)
df = df[df['yr_built']>q]

# %%
df = df.reset_index(drop=True)
df.describe(include='all')
# Out:
#                       Address  \
# count                     151
# unique                    151
# top     4965 SW Park Bluff Pl
# freq                        1
# mean                      NaN
# std                       NaN
# min                       NaN
# 25%                       NaN
# 50%                       NaN
# 75%                       NaN
# max                       NaN
#
#                                                      link         price  \
# count                                                 151  1.510000e+02
# unique                                                151           NaN
# top     https://www.redfin.com/OR/Lake-Oswego/4965-Par...           NaN
# freq                                                    1           NaN
# mean                                                  NaN  7.049048e+05
# std                                                   NaN  4.444198e+05
# min                                                   NaN  1.500000e+05
# 25%                                                   NaN  3.240000e+05
# 50%                                                   NaN  6.120940e+05
# 75%                                                   NaN  8.925000e+05
# max                                                   NaN  2.099000e+06
#
#               beds       baths        sqft view_yn     yr_built cooling_yn  \
# count   151.000000  151.000000  151.000000     151   151.000000        151
# unique         NaN         NaN         NaN       2          NaN          2
# top            NaN         NaN         NaN     Yes          NaN        Yes
# freq           NaN         NaN         NaN      83          NaN         94
# mean      2.973510    2.238411   42.315296     NaN  1979.894040        NaN
# std       1.070495    0.754618   10.781706     NaN    15.440705        NaN
# min       1.000000    1.000000   24.494897     NaN  1941.000000        NaN
# 25%       2.000000    2.000000   33.984574     NaN  1970.000000        NaN
# 50%       3.000000    2.000000   40.236799     NaN  1979.000000        NaN
# 75%       4.000000    2.500000   49.295021     NaN  1988.000000        NaN
# max       6.000000    4.500000   67.609171     NaN  2023.000000        NaN
#
#        has_hoa senior_community_yn                      style  \
# count      151                 151                        151
# unique       2                   2                          2
# top        Yes                  No  Single Family Residential
# freq        89                 149                         95
# mean       NaN                 NaN                        NaN
# std        NaN                 NaN                        NaN
# min        NaN                 NaN                        NaN
# 25%        NaN                 NaN                        NaN
# 50%        NaN                 NaN                        NaN
# 75%        NaN                 NaN                        NaN
# max        NaN                 NaN                        NaN
#
#                   county new_construction_yn   log_price
# count                151                 151  151.000000
# unique                 2                   2         NaN
# top     Clackamas County                  No         NaN
# freq                 112                 149         NaN
# mean                 NaN                 NaN   13.274740
# std                  NaN                 NaN    0.629456
# min                  NaN                 NaN   11.918391
# 25%                  NaN                 NaN   12.688456
# 50%                  NaN                 NaN   13.324641
# 75%                  NaN                 NaN   13.701746
# max                  NaN                 NaN   14.556972

# %% [markdown]
# ## Checking OLS Assumptions

# %%
f, [[ax1, ax2], [ax3, ax4]] = plt.subplots(2, 2, sharey=True, figsize=(10, 10))
ax1.scatter(df['beds'], df['price'])
ax1.set_title('price and beds')
ax2.scatter(df['baths'], df['price'])
ax2.set_title('price and baths')
ax3.scatter(df['sqft'], df['price'])
ax3.set_title('price and sqft')
ax4.scatter(df['yr_built'], df['price'])
ax4.set_title('price and yr_built')

plt.show()

# %% [markdown]
# ## Create Dummy variables

# %%
# Reorder columns
columns = ['Address', 'link', 'price', 'log_price', 'beds', 'baths', 'sqft', 'yr_built', 'view_yn', 'cooling_yn', 'senior_community_yn', 'style', 'county', 'new_construction_yn', 'has_hoa']
df = df[columns]
cleaned_df = df[columns]

# %%
df = pd.get_dummies(df, columns=df.columns[8:], drop_first=True)

# %%
df.head()
# Out:
#                  Address                                               link  \
# 0  4965 SW Park Bluff Pl  https://www.redfin.com/OR/Lake-Oswego/4965-Par...
# 1        3569 Sunwood Ct  https://www.redfin.com/OR/Lake-Oswego/3569-Sun...
# 2     6338 Washington Ct  https://www.redfin.com/OR/Lake-Oswego/6338-Was...
# 3       4672 Winthrop Ct  https://www.redfin.com/OR/Lake-Oswego/4672-Win...
# 4       16900 Gassner Ln  https://www.redfin.com/OR/Lake-Oswego/16900-Ga...
#
#      price  log_price  beds  baths       sqft  yr_built  view_yn_Yes  \
# 0  2099000  14.556972     5    4.5  67.586981      2022            1
# 1   700000  13.458836     3    1.5  36.742346      1966            0
# 2   800000  13.592367     2    1.5  39.849718      1958            1
# 3  1790000  14.397726     5    3.5  64.505814      2020            0
# 4  1622500  14.299479     4    3.5  62.872888      1973            0
#
#    cooling_yn_Yes  senior_community_yn_Yes  style_Single Family Residential  \
# 0               1                        0                                1
# 1               0                        0                                1
# 2               1                        0                                1
# 3               1                        0                                1
# 4               1                        0                                1
#
#    county_Multnomah County  new_construction_yn_Yes  has_hoa_Yes
# 0                        0                        1            1
# 1                        0                        0            0
# 2                        0                        0            0
# 3                        0                        0            1
# 4                        0                        0            0

# %% [markdown]
# ## Checking for multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables = df[['beds', 'baths', 'sqft', 'yr_built', 'view_yn_Yes', 'cooling_yn_Yes', 'senior_community_yn_Yes', 'style_Single Family Residential', 'county_Multnomah County', 'new_construction_yn_Yes', 'has_hoa_Yes']]
vif = pd.DataFrame()
vif['VIF'] = [variance_inflation_factor(variables.values, i) for i in range(variables.shape[1])]
vif["features"] = variables.columns

# %%
vif
# Out:
#      VIF                         features
# 0  39.06                             beds
# 1  45.96                            baths
# 2  99.48                             sqft
# 3  24.34                         yr_built
# 4   2.58                      view_yn_Yes
# 5   3.64                   cooling_yn_Yes
# 6   1.13          senior_community_yn_Yes
# 7   8.40  style_Single Family Residential
# 8   1.75          county_Multnomah County
# 9   1.19          new_construction_yn_Yes
# 10  3.49                      has_hoa_Yes

# %% [markdown]
# ## Linear Regression Model

# %%
targets = df['log_price']
inputs = df.drop(['Address', 'link', 'baths', 'beds', 'price', 'log_price', 'senior_community_yn_Yes', 'new_construction_yn_Yes', 'view_yn_Yes'], axis=1)

# %% [markdown]
# ### Scale the data

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(inputs)
# Out:
# StandardScaler()

# %%
inputs_scaled = scaler.transform(inputs)

# %%
inputs_scaled
# Out:
# array([[ 2.3517414 ,  2.73602021,  0.77870596,  0.7677719 , -0.59009684,
#          0.83464317],
#        [-0.51860951, -0.90282642, -1.28418177,  0.7677719 , -0.59009684,
#         -1.1981168 ],
#        [-0.22944263, -1.42266166,  0.77870596,  0.7677719 , -0.59009684,
#         -1.1981168 ],
#        [ 2.06501305,  2.6060614 ,  0.77870596,  0.7677719 , -0.59009684,
#          0.83464317],
#        [ 1.91305564, -0.44797059,  0.77870596,  0.7677719 , -0.59009684,
#         -1.1981168 ],
#        [-1.09684351, -0.05809417, -1.28418177, -1.30247018,  1.69463709,
#          0.83464317],
#        [ 0.58775376,  0.91659689,  0.77870596,  0.7677719 , -0.59009684,
#          0.83464317],
#        [ 0.95197977,  0.52672047,  0.77870596,  0.7677719 , -0.59009684,
#          0.83464317],
#        [-1.1274911 ,  0.00688523, -1.28418177, -1.30247018,  1.69463709,
#         -1.1981168 ],
#        [-0.27408071,  0.07186464,  0.77870596, -1.30247018,  1.69463709,
#          0.83464317],
#        [ 0.19676482,  2.02124676,  0.77870596,  0.7677719 , -0.59009684,
#          0.83464317],
#        [ 0.35602192,  2.02124676,  0.77870596,  0.7677719 , -0.59009684,
#          0.83464317],
#        [-0.34689669, -0.05809417, -1.28418177, -1.30247018,  1.69463709,
#          0.83464317],
#        [-0.31090286, -0.31801179,  0.77870596,  0.7677719 , -0.59009684,
#         -1.1981168 ],
#        [ 1.16856016,  0.52672047,  0.77870596,  0.7677719 , -0.59009684,
#          0.83464317],
#        [-0.202684  , -0.83784702,  0.77870596,  0.7677719 , -0.59009684,
#         -1.1981168 ],
#        [ 0.9723042 , -0.51295   , -1.28418177, -1.30247018,  1.69463709,
#          0.83464317],
#        [-0.87251117, -0.05809417,  0.77870596, -1.30247018,  1.69463709,
#          0.83464317],
#        [-1.3089962 , -0.05809417, -1.28418177, -1.30247018,  1.69463709,
#          0.83464317],
#        [-0.81097568,  1.11153511, -1.28418177, -1.30247018, -0.59009684,
#          0.83464317],
#        [-0.51734338, -0.64290881, -1.28418177, -1.30247018, -0.59009684,
#          0.83464317],
#        [ 1.43547203,  1.69634974,  0.77870596,  0.7677719 , -0.59009684,
#         -1.1981168 ],
#        [ 0.13769669, -1.42266166, -1.28418177,  0.7677719 ,  1.69463709,
#         -1.1981168 ],
#        [ 1.26016499, -0.70788821,  0.77870596,  0.7677719 , -0.59009684,
#          0.83464317],
#        [ 1.98148032, -0.12307357,  0.77870596,  0.7677719 , -0.59009684,
#         -1.1981168 ],
#        [-0.69273608,  0.07186464,  0.77870596, -1.30247018,  1.69463709,
#          0.83464317],
#        [ 1.57704444,  2.6710408 ,  0.77870596,  0.7677719 , -0.59009684,
#         -1.1981168 ],
#        [ 0.96347785,  0.13684404,  0.77870596,  0.7677719 ,  1.69463709,
#          0.83464317],
#        [ 0.5037344 ,  2.02124676,  0.77870596,  0.7677719 , -0.59009684,
#          0.83464317],
#        [-1.01866526, -0.64290881, -1.28418177, -1.30247018, -0.59009684,
#          0.83464317],
#        [-1.09684351, -0.05809417, -1.28418177, -1.30247018,  1.69463709,
#          0.83464317],
#        [ 0.35803827, -0.05809417,  0.77870596, -1.30247018,  1.69463709,
#          0.83464317],
#        [-0.7957801 , -0.12307357,  0.77870596, -1.30247018,  1.69463709,
#          0.83464317],
#        [-0.91375319, -0.5779294 ,  0.77870596, -1.30247018,  1.69463709,
#          0.83464317],
#        [-1.0335361 , -0.64290881,  0.77870596, -1.30247018, -0.59009684,
#          0.83464317],
#        
-1.28418177,  0.7677719 , -0.59009684,
#         -1.1981168 ],
#        [ 1.12341931, -0.51295   , -1.28418177, -1.30247018,  1.69463709,
#         -1.1981168 ],
#        [-1.62627019, -0.64290881, -1.28418177, -1.30247018, -0.59009684,
#          0.83464317],
#        [-0.33365722,  0.85161749,  0.77870596, -1.30247018, -0.59009684,
#          0.83464317],
#        [ 0.91375354,  0.72165868,  0.77870596,  0.7677719 , -0.59009684,
#          0.83464317],
#        [-0.62407799, -0.96780583, -1.28418177,  0.7677719 , -0.59009684,
#         -1.1981168 ],
#        [ 0.14830719, -1.09776464,  0.77870596,  0.7677719 , -0.59009684,
#         -1.1981168 ],
#        [-0.19342148, -1.35768225,  0.77870596,  0.7677719 , -0.59009684,
#         -1.1981168 ],
#        [-1.24713372,  0.52672047, -1.28418177, -1.30247018, -0.59009684,
#          0.83464317],
#        [ 0.06588101,  0.13684404,  0.77870596,  0.7677719 ,  1.69463709,
#          0.83464317],
#        [ 0.06371745, -0.31801179,  0.77870596,  0.7677719 , -0.59009684,
#          0.83464317],
#        [ 1.49238444,  0.85161749,  0.77870596,  0.7677719 , -0.59009684,
#          0.83464317],
#        [-1.05448412, -0.64290881,  0.77870596,  0.7677719 , -0.59009684,
#         -1.1981168 ],
#        [-0.27289906, -0.5779294 ,  0.77870596,  0.7677719 , -0.59009684,
#         -1.1981168 ],
#        [ 1.42175544,  0.20182345,  0.77870596,  0.7677719 , -0.59009684,
#          0.83464317],
#        [ 1.11142793,  0.65667928, -1.28418177,  0.7677719 , -0.59009684,
#         -1.1981168 ],
#        [ 0.84091553,  0.78663808,  0.77870596,  0.7677719 , -0.59009684,
#         -1.1981168 ],
#        [-1.24713372,  0.52672047, -1.28418177, -1.30247018, -0.59009684,
#          0.83464317],
#        [-1.1274911 , -1.09776464, -1.28418177,  0.7677719 , -0.59009684,
#         -1.1981168 ],
#        [ 0.83184604,  0.65667928,  0.77870596,  0.7677719 ,  1.69463709,
#          0.83464317],
#        [-1.22629424,  0.33178226, -1.28418177, -1.30247018, -0.59009684,
#         -1.1981168 ],
#        [ 0.21974055, -0.64290881,  0.77870596,  0.7677719 , -0.59009684,
#          0.83464317],
#        [-1.1090627 ,  0.33178226, -1.28418177, -1.30247018, -0.59009684,
#         -1.1981168 ],
#        [ 0.65235339, -0.25303238,  0.77870596,  0.7677719 , -0.59009684,
#          0.83464317],
#        [ 0.40714652, -1.61759987,  0.77870596,  0.7677719 , -0.59009684,
#         -1.1981168 ],
#        [-0.11786252, -0.05809417, -1.28418177,  0.7677719 , -0.59009684,
#         -1.1981168 ],
#        [-0.75470631, -0.31801179,  0.77870596, -1.30247018, -0.59009684,
#          0.83464317],
#        [-1.36560768, -0.12307357,  0.77870596, -1.30247018,  1.69463709,
#          0.83464317],
#        [ 1.91971232,  2.41112319,  0.77870596,  0.7677719 , -0.59009684,
#         -1.1981168 ],
#        [ 1.28841044,  0.46174106,  0.77870596,  0.7677719 , -0.59009684,
#          0.83464317],
#        [ 1.44513328,  0.52672047,  0.77870596,  0.7677719 , -0.59009684,
#          0.83464317],
#        [-0.63454788, -0.31801179, -1.28418177, -1.30247018, -0.59009684,
#          0.83464317],
#        [-0.70075187, -0.05809417,  0.77870596,  0.7677719 , -0.59009684,
#          0.83464317],
#        [ 1.04582844, -0.44797059, -1.28418177,  0.7677719 , -0.59009684,
#          0.83464317],
#        [ 0.08530072, -1.74755868,  0.77870596,  0.7677719 , -0.59009684,
#          0.83464317]])

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(inputs_scaled, targets, test_size=0.2, random_state=47)

# %% [markdown]
# ### Regression

# %%
reg = LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_hat = reg.predict(x_train)
plt.scatter(y_train, y_hat)

# %%
sns.displot(y_train - y_hat)
plt.title("Residuals PDF")
# Out:
# Text(0.5, 1.0, 'Residuals PDF')

# %%
reg.score(x_train, y_train)
# Out:
# 0.9361381695414163

# %%
reg.score(x_test, y_test)
# Out:
# 0.8825574177364462

# %%
def adj_r2(x,y):
    r2 = reg.score(x,y)
    n = x.shape[0]
    p = x.shape[1]
    adjusted_r2 = 1-(1-r2)*(n-1)/(n-p-1)
    return adjusted_r2

# %%
adj_r2(x_train, y_train)
# Out:
# 0.9327472758887481

# %%
reg_summary = pd.DataFrame(inputs.columns.values, columns=['Features'])
reg_summary['Weights'] = (np.exp(reg.coef_ / scaler.scale_) - 1) * 100

# %%
from sklearn.feature_selection import f_regression
f_stat, p_values = f_regression(x_train, y_train)

# %%
reg_summary['f_stat'] = f_stat.round(3)
reg_summary['p_value'] = p_values.round(3)
reg_summary
# Out:
#                           Features    Weights   f_stat  p_value
# 0                             sqft   3.277455  422.535      0.0
# 1                         yr_built   0.342234   15.658      0.0
# 2                   cooling_yn_Yes   6.231194   22.850      0.0
# 3  style_Single Family Residential  69.249830  280.279      0.0
# 4          county_Multnomah County -12.374009   23.019      0.0
# 5                      has_hoa_Yes -10.048363   15.274      0.0

# %%
y_hat_test = reg.predict(x_test)

# %%
plt.scatter(y_test, y_hat_
# 16        13.393684  6.558478e+05   13.429848   680000.0   24152.189224
# 17        13.303549  5.993187e+05   13.458836   700000.0  100681.291953
# 18        12.309862  2.218734e+05   12.301383   220000.0   -1873.416106
# 19        13.117669  4.976584e+05   13.017003   450000.0  -47658.443975
# 20        12.494141  2.667698e+05   12.524526   275000.0    8230.192391
# 21        12.511819  2.715276e+05   12.487485   265000.0   -6527.622705
# 22        14.014196  1.219798e+06   13.910821  1100000.0 -119797.871698
# 23        13.263583  5.758386e+05   13.321214   610000.0   34161.383110
# 24        13.234787  5.594932e+05   13.976779  1175000.0  615506.826089
# 25        13.249915  5.680215e+05   13.400071   660050.0   92028.507253
# 26        13.763715  9.495226e+05   13.174956   527000.0 -422522.579437
# 27        13.486840  7.198802e+05   13.345507   625000.0  -94880.242431
# 28        13.714940  9.043212e+05   13.681979   875000.0  -29321.210192
# 29        12.743291  3.422481e+05   12.793859   360000.0   17751.945745
# 30        13.383222  6.490221e+05   13.384728   650000.0     977.861104
#
#     Difference%
# 0        -10.42
# 1         10.67
# 2         -6.79
# 3         11.56
# 4        -18.79
# 5         -0.40
# 6          7.76
# 7        -31.46
# 8          8.33
# 9          5.21
# 10       -46.65
# 11         5.80
# 12       -18.04
# 13        12.40
# 14        -2.46
# 15         2.06
# 16         3.55
# 17        14.38
# 18        -0.85
# 19       -10.59
# 20         2.99
# 21        -2.46
# 22       -10.89
# 23         5.60
# 24        52.38
# 25        13.94
# 26       -80.18
# 27       -15.18
# 28        -3.35
# 29         4.93
# 30         0.15

# %%
import scipy.stats as stats
SE_residual = np.sqrt(np.sum(df_pf['residual']**2) / (len(y_test) - x_test.shape[1]))
margin_error = SE_residual*stats.t.ppf(.8, len(x_test) - 1)
df_pf['lower_bound'] = df_pf['predictions'] - margin_error
df_pf['upper_bound'] = df_pf['predictions'] + margin_error
df_pf
# Out:
#     log_predictions   predictions  log_target     target       residual  \
# 0         13.659750  8.557642e+05   13.560618   775000.0  -80764.177274
# 1         14.444128  1.875017e+06   14.556972  2099000.0  223983.161642
# 2         13.639108  8.382805e+05   13.573439   785000.0  -53280.450640
# 3         12.383383  2.388003e+05   12.506177   270000.0   31199.732383
# 4         13.476895  7.127567e+05   13.304685   600000.0 -112756.659158
# 5         12.710804  3.313082e+05   12.706848   330000.0   -1308.212653
# 6         12.425366  2.490394e+05   12.506177   270000.0   20960.617192
# 7         13.584864  7.940198e+05   13.311329   604000.0 -190019.787235
# 8         12.494141  2.667698e+05   12.581079   291000.0   24230.192391
# 9         12.574574  2.891134e+05   12.628067   305000.0   15886.589420
# 10        12.301257  2.199722e+05   11.918391   150000.0  -69972.237660
# 11        14.337931  1.686104e+06   14.397726  1790000.0  103896.346093
# 12        13.847856  1.032874e+06   13.681979   875000.0 -157874.369276
# 13        13.490649  7.226277e+05   13.623017   824900.0  102272.318436
# 14        13.348816  6.270718e+05   13.324488   612000.0  -15071.776608
# 15        12.518157  2.732539e+05   12.538967   279000.0    5746.115273
# 16        13.393684  6.558478e+05   13.429848   680000.0   24152.189224
# 17        13.303549  5.993187e+05   13.458836   700000.0  100681.291953
# 18        12.309862  2.218734e+05   12.301383   220000.0   -1873.416106
# 19        13.117669  4.976584e+05   13.017003   450000.0  -47658.443975
# 20        12.494141  2.667698e+05   12.524526   275000.0    8230.192391
# 21        12.511819  2.715276e+05   12.487485   265000.0   -6527.622705
# 22        14.014196  1.219798e+06   13.910821  1100000.0 -119797.871698
# 23        13.263583  5.758386e+05   13.321214   610000.0   34161.383110
# 24        13.234787  5.594932e+05   13.976779  1175000.0  615506.826089
# 25        13.249915  5.680215e+05   13.400071   660050.0   92028.507253
# 26        13.763715  9.495226e+05   13.174956   527000.0 -422522.579437
# 27        13.486840  7.198802e+05   13.345507   625000.0  -94880.242431
# 28        13.714940  9.043212e+05   13.681979   875000.0  -29321.210192
# 29        12.743291  3.422481e+05   12.793859   360000.0   17751.945745
# 30        13.383222  6.490221e+05   13.384728   650000.0     977.861104
#
#     Difference%   lower_bound   upper_bound
# 0        -10.42  7.062612e+05  1.005267e+06
# 1         10.67  1.725514e+06  2.024520e+06
# 2         -6.79  6.887775e+05  9.877834e+05
# 3         11.56  8.929731e+04  3.883032e+05
# 4        -18.79  5.632537e+05  8.622596e+05
# 5         -0.40  1.818053e+05  4.808112e+05
# 6          7.76  9.953643e+04  3.985423e+05
# 7        -31.46  6.445168e+05  9.435227e+05
# 8          8.33  1.172669e+05  4.162728e+05
# 9          5.21  1.396105e+05  4.386164e+05
# 10       -46.65  7.046928e+04  3.694752e+05
# 11         5.80  1.536601e+06  1.835607e+06
# 12       -18.04  8.833714e+05  1.182377e+06
# 13        12.40  5.731247e+05  8.721306e+05
# 14        -2.46  4.775688e+05  7.765747e+05
# 15         2.06  1.237509e+05  4.227568e+05
# 16         3.55  5.063449e+05  8.053508e+05
# 17        14.38  4.498158e+05  7.488217e+05
# 18        -0.85  7.237046e+04  3.713764e+05
# 19       -10.59  3.481555e+05  6.471614e+05
# 20         2.99  1.172669e+05  4.162728e+05
# 21        -2.46  1.220247e+05  4.210306e+05
# 22       -10.89  1.070295e+06  1.369301e+06
# 23         5.60  4.263357e+05  7.253416e+05
# 24        52.38  4.099902e+05  7.089961e+05
# 25        13.94  4.185185e+05  7.175244e+05
# 26       -80.18  8.000196e+05  1.099026e+06
# 27       -15.18  5.703773e+05  8.693832e+05
# 28        -3.35  7.548183e+05  1.053824e+06
# 29         4.93  1.927451e+05  4.917510e+05
# 30         0.15  4.995192e+05  7.985251e+05

# %% [markdown]
# # Writing predictions to csv

# %%
predicted_price = np.exp(reg.predict(inputs_scaled))
cleaned_df['predicted_price'] = predicted_price
pd.set_option('display.float_format', lambda x: '%.2f' % x)
cleaned_df['difference'] = cleaned_df['predicted_price'] - cleaned_df['price']
cleaned_df['difference%'] = 100*cleaned_df['difference']/cleaned_df['price']
column_order = ['Address', 'link', 'price', 'predicted_price', 'difference', 'difference%', 'beds', 'baths', 'sqft',
       'yr_built', 'view_yn', 'cooling_yn', 'senior_community_yn', 'style',
       'county', 'new_construction_yn', 'has_hoa']
cleaned_df = cleaned_df[column_order]
cleaned_df
# Out:
#                    Address                                               link  \
# 0    4965 SW Park Bluff Pl  https://www.redfin.com/OR/Lake-Oswego/4965-Par...
# 1          3569 Sunwood Ct  https://www.redfin.com/OR/Lake-Oswego/3569-Sun...
# 2       6338 Washington Ct  https://www.redfin.com/OR/Lake-Oswego/6338-Was...
# 3         4672 Winthrop Ct  https://www.redfin.com/OR/Lake-Oswego/4672-Win...
# 4         16900 Gassner Ln  https://www.redfin.com/OR/Lake-Oswego/16900-Ga...
# ..                     ...                                                ...
# 146      5254 Westfield Ct  https://www.redfin.com/OR/Lake-Oswego/5254-Wes...
# 147          4638 Lower Dr  https://www.redfin.com/OR/Lake-Oswego/4638-Low...
# 148      4324 Woodside Cir  https://www.redfin.com/OR/Lake-Oswego/4324-Woo...
# 149      110 Greenridge Ct  https://www.redfin.com/OR/Lake-Oswego/110-Gree...
# 150        4487 Westbay Rd  https://www.redfin.com/OR/Lake-Oswego/4487-Wes...
#
#        price  predicted_price  difference  difference%  beds  baths  sqft  \
# 0    2099000       1875016.84  -223983.16       -10.67     5   4.50 67.59
# 1     700000        599318.71  -100681.29       -14.38     3   1.50 36.74
# 2     800000        684794.33  -115205.67       -14.40     2   1.50 39.85
# 3    1790000       1686103.65  -103896.35        -5.80     5   3.50 64.51
# 4    1622500       1514496.47  -108003.53        -6.66     4   3.50 62.87
# ..       ...              ...         ...          ...   ...    ...   ...
# 146  1300000       1219299.12   -80700.88        -6.21     4   2.50 57.84
# 147   307500        315532.08     8032.08         2.61     2   1.50 35.50
# 148   579000        562075.95   -16924.05        -2.92     2   2.00 34.79
# 149   527000        949522.58   422522.58        80.18     3   2.50 53.55
# 150  1200000        675336.32  -524663.68       -43.72     3   2.00 43.23
#
#      yr_built view_yn cooling_yn senior_community_yn  \
# 0        2022     Yes        Yes                  No
# 1        1966      No         No                  No
# 2        1958     Yes        Yes                  No
# 3        2020      No        Yes                  No
# 4        1973      No        Yes                  No
# ..        ...     ...        ...                 ...
# 146      1988     Yes        Yes                  No
# 147      1975      No         No                  No
# 148      1979     Yes        Yes                  No
# 149      1973      No         No                  No
# 150      1953     Yes        Yes                  No
#
#                          style            county new_construction_yn has_hoa
# 0    Single Family Residential  Clackamas County                 Yes     Yes
# 1    Single Family Residential  Clackamas County                  No      No
# 2    Single Family Residential  Clackamas County                  No      No
# 3    Single Family Residential  Clackamas County                  No     Yes
# 4    Single Family Residential  Clackamas County                  No      No
# ..                         ...               ...                 ...     ...
# 146  Single Family Residential  Clackamas County                  No     Yes
# 147                Condo/Co-op  Clackamas County                  No     Yes
# 148  Single Family Residential  Clackamas County                  No     Yes
# 149  Single Family Residential  Clackamas County                  No     Yes
# 150  Single Family Residential  Clackamas County                  No     Yes
#
# [151 rows x 17 columns]

# %%
cleaned_df.to_csv('predictions.csv')

# %%
d = {'sqft': [1800], 'yr_built': [1999], 'cooling_yn_Yes': [1], 'style_Single Family Residential': [0], 'county_Multnomah County': [0], 'has_hoa_Yes': [1]}
ka_home = pd.DataFrame(data=d)
ka_home_scaled = scaler.transform(ka_home)
ka_hat = reg.predict(ka_home_scaled)

# %%
np.exp(ka_hat)
# Out:
# array([1.87805564e+30])

# %%
np.exp(ka_hat) - margin_error
# Out:
# array([1.87805564e+30])

# %%
np.exp(ka_hat) + margin_error
# Out:
# array([1.87805564e+30])
