# %%
import re
import pandas as pd

# %%
zipcode = '97035'
filename = zipcode + '_homes_data.csv'
df = pd.read_csv(filename)
df.rename(columns={'Unnamed: 0': 'Address'}, inplace=True)

# %%
df
# Out:
#                    Address                                               link  \
# 0    4965 SW Park Bluff Pl  https://www.redfin.com/OR/Lake-Oswego/4965-Par...
# 1          3569 Sunwood Ct  https://www.redfin.com/OR/Lake-Oswego/3569-Sun...
# 2          5225 Firwood Rd  https://www.redfin.com/OR/Lake-Oswego/5225-Fir...
# 3         38 Cervantes Cir  https://www.redfin.com/OR/Lake-Oswego/38-Cerva...
# 4         3119 Douglas Cir  https://www.redfin.com/OR/Lake-Oswego/3119-Dou...
# ..                     ...                                                ...
# 171      5254 Westfield Ct  https://www.redfin.com/OR/Lake-Oswego/5254-Wes...
# 172          4638 Lower Dr  https://www.redfin.com/OR/Lake-Oswego/4638-Low...
# 173      4324 Woodside Cir  https://www.redfin.com/OR/Lake-Oswego/4324-Woo...
# 174      110 Greenridge Ct  https://www.redfin.com/OR/Lake-Oswego/110-Gree...
# 175        4487 Westbay Rd  https://www.redfin.com/OR/Lake-Oswego/4487-Wes...
#
#           price beds baths   sqft             parking_features  parking_total  \
# 0    $2,099,000    5   4.5  4,568          Driveway, On Street            2.0
# 1      $700,000    3   1.5  1,350         Driveway, Off Street            2.0
# 2    $1,550,000    3   2.5  3,240  Driveway, RV Access/Parking            2.0
# 3      $293,000    2   1.5    912                   Off Street            1.0
# 4    $2,675,000    4     6  6,524            RV Access/Parking           14.0
# ..          ...  ...   ...    ...                          ...            ...
# 171  $1,300,000    4   2.5  3,346                     Driveway            3.0
# 172    $307,500    2   1.5  1,260                          NaN            NaN
# 173    $579,000    2     2  1,210          Driveway, On Street            2.0
# 174    $527,000    3   2.5  2,868            Off Street, Other            2.0
# 175  $1,200,000    3     2  1,869                     Driveway            2.0
#
#                          garage_type  garage_spaces  ...         fuel_desc  \
# 0                           Attached            2.0  ...               Gas
# 1                Attached, Oversized            2.0  ...               Gas
# 2    Attached, Extra Deep, Oversized            2.0  ...               Gas
# 3                              Other            1.0  ...       Electricity
# 4      Attached, Detached, Oversized           14.0  ...  Electricity, Gas
# ..                               ...            ...  ...               ...
# 171                         Attached            3.0  ...               Gas
# 172                             None            NaN  ...       Electricity
# 173                         Detached            2.0  ...  Electricity, Gas
# 174                         Attached            2.0  ...               Gas
# 175                         Detached            2.0  ...               Oil
#
#                                                  sewer  cooling_yn has_hoa  \
# 0                                         Public Sewer         Yes     Yes
# 1                                         Public Sewer          No     NaN
# 2                                          Septic Tank         Yes     NaN
# 3    All Landscaping, Athletic Court, Basketball Co...          No     Yes
# 4                                         Public Sewer         Yes     NaN
# ..                                                 ...         ...     ...
# 171                                       Public Sewer         Yes     Yes
# 172                                       Public Sewer          No     Yes
# 173                                       Public Sewer         Yes     Yes
# 174                                       Public Sewer          No     Yes
# 175                                       Public Sewer         Yes     Yes
#
#     senior_community_yn stories                      style yr_renovated  \
# 0                    No       —  Single Family Residential            —
# 1                    No     1.0  Single Family Residential            —
# 2                    No     1.0  Single Family Residential            —
# 3                    No       —                Condo/Co-op            —
# 4                    No     2.0  Single Family Residential            —
# ..                  ...     ...                        ...          ...
# 171                  No     2.0  Single Family Residential            —
# 172                  No       —                Condo/Co-op            —
# 173                  No     1.0  Single Family Residential            —
# 174                  No     2.0  Single Family Residential            —
# 175                  No     1.0  Single Family Residential            —
#
#                county new_construction_yn
# 0    Clackamas County                 Yes
# 1    Clackamas County                  No
# 2    Clackamas County                  No
# 3    Multnomah County                  No
# 4    Clackamas County                  No
# ..                ...                 ...
# 171  Clackamas County                  No
# 172  Clackamas County                  No
# 173  Clackamas County                  No
# 174  Clackamas County                  No
# 175  Clackamas County                  No
#
# [176 rows x 31 columns]

# %% [markdown]
# ## Convert price to float, then remove any rows where values are null or not numeric where expected

# %%
df['price'] = df['price'].str.replace('[$,]', '', regex=True)
df = df[pd.to_numeric(df['price'], errors='coerce').notnull()]
df = df[pd.to_numeric(df['beds'], errors='coerce').notnull()]
df = df[pd.to_numeric(df['baths'], errors='coerce').notnull()]
df['sqft'] = df['sqft'].str.replace('[,]', '', regex=True)
df = df[pd.to_numeric(df['sqft'], errors='coerce').notnull()]
df = df[pd.to_numeric(df['yr_built'], errors='coerce').notnull()]

# %% [markdown]
# ## Remove unexpected categorical values from style

# %%
styles = ['Single Family Residential', 'Condo/Co-op', 'Townhouse']
df = df[df['style'].isin(styles)]

# %% [markdown]
# ## Explore count of unique and null values to determine which variables to use

# %%
column_stats = {}
for col in df.columns:
    column_stats[col] = {}
    column_stats[col]['value_count'] = df[col].value_counts()
    column_stats[col]['null_count'] = df[col].isna().sum()

for col in column_stats:
    print(col)
    print()
    print('VALUE COUNT')
    print('****************************')
    print(column_stats[col]['value_count'])
    print()
    print('NULL COUNT')
    print('****************************')
    print(column_stats[col]['null_count'])
    print('\n\n\n')
# Out:
# Address
#
# VALUE COUNT
# ****************************
# 4965 SW Park Bluff Pl      1
# 2815 SW Orchard Hill Pl    1
# 2121 Wembley Park Rd       1
# 23 Tanglewood Dr           1
# 5754 Charles Cir           1
#                           ..
# 4694 Winthrop Ct           1
# 18521 Don Lee Way          1
# 4 Touchstone #117          1
# 4322 Collins Way           1
# 4487 Westbay Rd            1
# Name: Address, Length: 163, dtype: int64
#
# NULL COUNT
# ****************************
# 0
#
#
#
#
# link
#
# VALUE COUNT
# ****************************
# https://www.redfin.com/OR/Lake-Oswego/4965-Park-Bluff-Pl-97035/home/183781964      1
# https://www.redfin.com/OR/Lake-Oswego/2815-Orchard-Hill-Pl-97035/home/26485233     1
# https://www.redfin.com/OR/Lake-Oswego/2121-Wembley-Park-Rd-97034/home/26055635     1
# https://www.redfin.com/OR/Lake-Oswego/23-Tanglewood-Dr-97035/home/25940174         1
# https://www.redfin.com/OR/Lake-Oswego/5754-Charles-Cir-97035/home/26004817         1
#                                                                                   ..
# https://www.redfin.com/OR/Lake-Oswego/4694-Winthrop-Ct-97035/home/25979480         1
# https://www.redfin.com/OR/Lake-Oswego/18521-Don-Lee-Way-97035/home/26048331        1
# https://www.redfin.com/OR/Lake-Oswego/4-Touchstone-97035/unit-117/home/25970747    1
# https://www.redfin.com/OR/Lake-Oswego/4322-Collins-Way-97035/home/25944869         1
# https://www.redfin.com/OR/Lake-Oswego/4487-Westbay-Rd-97035/home/25924517          1
# Name: link, Length: 163, dtype: int64
#
# NULL COUNT
# ****************************
# 0
#
#
#
#
# price
#
# VALUE COUNT
# ****************************
# 275000     4
# 307500     2
# 875000     2
# 610000     2
# 1175000    2
#           ..
# 854705     1
# 715000     1
# 360000     1
# 344000     1
# 1200000    1
# Name: price, Length: 145, dtype: int64
#
# NULL COUNT
# ****************************
# 0
#
#
#
#
# beds
#
# VALUE COUNT
# ****************************
# 3    58
# 2    42
# 4    36
# 5    15
# 1    10
# 6     2
# Name: beds, dtype: int64
#
# NULL COUNT
# ****************************
# 0
#
#
#
#
# baths
#
# VALUE COUNT
# ****************************
# 2.5    52
# 2      49
# 1      19
# 3      12
# 1.5    10
# 3.5     7
# 4.5     5
# 4       4
# 5.5     3
# 6       1
# 6.5     1
# Name: baths, dtype: int64
#
# NULL COUNT
# ****************************
# 0
#
#
#
#
# sqft
#
# VALUE COUNT
# ****************************
# 617     4
# 984     3
# 1351    3
# 1212    3
# 1259    2
#        ..
# 1699    1
# 1136    1
# 1175    1
# 1886    1
# 1869    1
# Name: sqft, Length: 142, dtype: int64
#
# NULL COUNT
# ****************************
# 0
#
#
#
#
# parking_features
#
# VALUE COUNT
# ****************************
# Driveway                       36
# Driveway, On Street            25
# Driveway, Off Street           15
# Off Street                     13
# Driveway, RV Access/Parking     6
# Carport, Off Street             4
# Carport                         3
# Deeded                          3
# Driveway, Secured               3
# Other                           2
# Covered, Off Street             2
# Carport, Covered                2
# Deeded, Parking Pad             2
# Off Street, On Street           2
# On Street                       2
# Carport, Driveway               1
# Carport, Parking Pad            1
# Off Street, Parking Pad         1
# Carport, Deeded                 1
# Carport, Other                  1
# Parking Pad                     1
# Attached Garage, Off Street     1
# Deeded, Off Street              1
# RV Access/Parking               1
# Other, Parking Pad              1
# Covered, Parking Pad            1
# Driveway, Other                 1
# Off Street, Other               1
# Name: parking_features, dtype: int64
#
# NULL COUNT
# ****************************
# 30
#
#
#
#
# parking_total
#
# VALUE COUNT
# ****************************
# 2.0     64
# 1.0     32
# 3.0     15
# 4.0      4
# 5.0      2
# 14.0     1
# 21.0     1
# Name: parking_total, dtype: int64
#
# NULL COUNT
# ****************************
# 44
#
#
#
#
# garage_type
#
# VALUE COUNT
# ****************************
# Attached                                         77
# Other                                            13
# Attached, Oversized                              11
# Detached                                          5
# Deeded                                            5
# Undeeded                                          5
# None                                              5
# Carport                                           2
# Attached, Detached                                2
# Attached, Tandem                                  2
# Attached, Partially Converted to Living Space     2
# Attached, Extra Deep                              2
# Detached, Oversized                               2
# Attached, Detached, Oversized                     2
# Attached, Extra Deep, Oversized                   2
# Attached, Oversized, Tuck-Under                   1
# Oversized                                         1
# Name: garage_type, dtype: int64
#
# NULL COUNT
# ****************************
# 24
#
#
#
#
# garage_spaces
#
# VALUE COUNT
# ****************************
# 2.0     64
# 1.0     32
# 3.0     15
# 4.0      4
# 5.0      2
# 14.0     1
# 21.0     1
# Name: garage_spaces, dtype: int64
#
# NULL COUNT
# ****************************
# 44
#
#
#
#
# hot_water_desc
#
# VALUE COUNT
# ****************************
# Gas                                          57
# Electricity                                  57
# Gas, Tankless                                 6
# Gas, Tank                                     5
# Tankless                                      4
# ENERGY STAR Qualified Equipment, Gas          2
# Electricity, Tank                             2
# ENERGY STAR Qualified Equipment, Tankless     2
# Other                                         1
# ENERGY STAR Qualified Equipment, Tank         1
# Recirculating, Tankless                       1
# Electricity, Gas                              1
# Name: hot_water_desc, dtype: int64
#
# NULL COUNT
# ****************************
# 24
#
#
#
#
# fireplace_yn
#
# VALUE COUNT
# ****************************
# Yes    111
# Name: fireplace_yn, dtype: int64
#
# NULL COUNT
# ****************************
# 52
#
#
#
#
# fireplace_total
#
# VALUE COUNT
# ****************************
# 1.0    77
# 2.0    25
# 3.0     7
# 4.0     1
# 7.0     1
# Name: fireplace_total, dtype: int64
#
# NULL COUNT
# ****************************
# 52
#
#
#
#
# basement
#
# VALUE COUNT
# ****************************
# Crawl Space                                            74
# Daylight                                                4
# No                                                      4
# Finished                                                3
# Daylight, Finished                                      2
# Daylight, Finished, Storage Space                       2
# Finished, Storage Space                                 2
# Storage Space                                           2
# Daylight, Finished, Full Basement                       2
# Exterior Entry, Full Basement                           1
# Other                                                   1
# Finished, Partial Basement                              1
# Crawl Space, Finished, Storage Space                    1
# Crawl Space, Storage Space                              1
# Exterior Entry, Finished                                1
# None                                                    1
# Separate Living Quarters/Apartment/Aux Living Unit      1
# Partial Basement, Partially Finished, Storage Space     1
# Daylight, Exterior Entry, Finished                      1
# Crawl Space, Exterior Entry, Storage Space              1
# Finished, Full Basement                                 1
# Name: basement, dtype: int64
#
# NULL COUNT
# ****************************
# 56
#
#
#
#
# roof
#
# VALUE COUNT
# ****************************
# Composition              94
# Tile                     17
# Shake                     5
# Metal                     5
# Composition, Shingle      4
# Concrete Tile             3
# Flat                      3
# Other, Tile               2
# Composition, Metal        2
# Composition, Membrane     1
# Clay Tile                 1
# Flat, Metal               1
# Other                     1
# Shake, Tile               1
# Shingle                   1
# Shake, Shingle            1
# Built-Up                  1
# Membrane                  1
# Name: roof, dtype: int64
#
# NULL COUNT
# ****************************
# 19
#
#
#
#
# lot_size_sqft
#
# VALUE COUNT
# ****************************
# 10,454    7
# 10,018    7
# 9,147     6
# 7,405     3
# 11,761    3
# 7,840     3
# 10,890    3
# 12,632    3
# 5,662     3
# 13,068    2
# 8,712     2
# 2,613     2
# 3,920     2
# 9,583     1
# 8,276     1
# 17,424    1
# 19,602    1
# 6,534     1
# 14,374    1
# 43,560    1
# 18,295    1
# 32,234    1
# 3,049     1
# 22,215    1
# 47,480    1
# 20,908    1
# 11,325    1
# Name: lot_size_sqft, dtype: int64
#
# NULL COUNT
# ****************************
# 103
#
#
#
#
# lot_size
#
# VALUE COUNT
# ****************************
# —                     56
# 0.26 acres             4
# 0.3 acres              3
# 0.25 acres             3
# 10,000 square feet     3
#                       ..
# 7,800 square feet      1
# 10,590 square feet     1
# 9,241 square feet      1
# 8,547 square feet      1
# 1,919 square feet      1
# Name: lot_size, Length: 90, dtype: int64
#
# NULL COUNT
# ****************************
# 0
#
#
#
#
# property_type
#
# VALUE COUNT
# ****************************
# Residential    145
# Name: property_type, dtype: int64
#
# NULL COUNT
# ****************************
# 18
#
#
#
#
# main_level_area
#
# VALUE COUNT
# ****************************
# 617      4
# 836      3
# 1,000    2
# 1,584    2
# 675      2
#         ..
# 1,175    1
# 1,886    1
# 1,012    1
# 1,260    1
# 1,869    1
# Name: main_level_area, Length: 127, dtype: int64
#
# NULL COUNT
# ****************************
# 20
#
#
#
#
# view_yn
#
# VALUE COUNT
# ****************************
# Yes    90
# No     54
# Name: view_yn, dtype: int64
#
# NULL COUNT
# ****************************
# 19
#
#
#
#
# yr_built
#
# VALUE COUNT
# ****************************
# 1970    17
# 1979    15
# 1978     8
# 1988     8
# 1971     6
# 2023     5
# 1985     5
# 1975     5
# 1992     4
# 1973     4
# 1980     4
# 1963     3
# 1964     3
# 1969     3
# 1997     3
# 1972     3
# 2011     3
# 1981     3
# 1994     3
# 1990     3
# 1966     3
# 1984     2
# 1991     2
# 1998     2
# 1968     2
# 1987     2
# 1959     2
# 1965     2
# 1983     2
# 1993     2
# 2022     2
# 2017     2
# 1977     2
# 1982     2
# 1958     2
# 2006     1
# 1955     1
# 1976     1
# 2000     1
# 2007     1
# 1936     1
# 1940     1
# 2001     1
# 2020     1
# 1956     1
# 1967     1
# 1999     1
# 1974     1
# 2003     1
# 2012     1
# 2021     1
# 1960     1
# 1947     1
# 1935     1
# 2018     1
# 1920     1
# 1941     1
# 1948     1
# 1953     1
# Name: yr_built, dtype: int64
#
# NULL COUNT
# ****************************
# 0
#
#
#
#
# fuel_desc
#
# VALUE COUNT
# ****************************
# Gas                 80
# Electricity         54
# Electricity, Gas     8
# Gas, Solar           1
# Oil                  1
# Name: fuel_desc, dtype: int64
#
# NULL COUNT
# ****************************
# 19
#
#
#
#
# sewer
#
# VALUE COUNT
# ****************************
# Public Sewer                                                                                                                                                                                                                                                                                         91
# Septic Tank                                                                                                                                                                                                                                                                                          18
# Standard Septic                                                                                                                                                                                                                                                                                       2
# Commons, Exterior Maintenance, Insurance, Management, Pool, Recreation Facilities, Sewer, Trash, Water                                                                                                                                                                                                1
# All Landscaping, Athletic Court, Basketball Court, Commons, Exterior Maintenance, Front Yard Landscaping, Gym, Lap Pool, Maintenance Grounds, Management, Meeting Room, Party Room, Pool, Recreation Facilities, Road Maintenance, Sauna, Sewer, Spa/Hot Tub, Tennis Court(s), Water, Weight Room     1
# All Landscaping, Commons, Exterior Maintenance, Insurance, Management, Sewer, Water                                                                                                                                                                                                                   1
# All Landscaping, Athletic Court, Exterior Maintenance, Gym, Lap Pool, Maintenance Grounds, Management, Recreation Facilities, Sewer, Spa/Hot Tub, Tennis Court(s), Trash, Water, Weight Room                                                                                                          1
# Sewer Connected                                                                                                                                                                                                                                                                                       1
# Electricity, Gym, Maintenance Grounds, Management, Meeting Room, Pool, Racquetball, Sewer, Tennis Court(s), Trash, Water                                                                                                                                                                              1
# Athletic Court, Basketball Court, Commons, Exterior Maintenance, Gym, Insurance, Lap Pool, Maintenance Grounds, Management, Meeting Room, Party Room, Pool, Recreation Facilities, Sauna, Sewer, Spa/Hot Tub, Trash, Water, Weight Room                                                               1
# Exterior Maintenance, Gym, Maintenance Grounds, Management, Pool, Sewer, Trash, Water                                                                                                                                                                                                                 1
# All Landscaping, Athletic Court, Basketball Court, Commons, Exterior Maintenance, Gym, Insurance, Lap Pool, Maintenance Grounds, Management, Meeting Room, Party Room, Pool, Recreation Facilities, Sauna, Sewer, Spa/Hot Tub, Trash, Utilities, Water, Weight Room                                   1
# Athletic Court, Commons, Gym, Insurance, Maintenance Grounds, Management, Pool, Sauna, Sewer, Spa/Hot Tub, Tennis Court(s), Trash, Water, Weight Room                                                                                                                                                 1
# Basketball Court, Exterior Maintenance, Gym, Lap Pool, Maintenance Grounds, Management, Meeting Room, Party Room, Pool, Recreation Facilities, Sauna, Sewer, Spa/Hot Tub, Trash, Water, Weight Room                                                                                                   1
# All Landscaping, Athletic Court, Basketball Court, Commons, Exterior Maintenance, Gym, Insurance, Lap Pool, Maintenance Grounds, Management, Meeting Room, Pool, Recreation Facilities, Sewer, Tennis Court(s), Trash, Weight Room                                                                    1
# Commons, Exterior Maintenance, Pool, Sewer, Trash, Water                                                                                                                                                                                                                                              1
# All Landscaping, Athletic Court, Basketball Court, Commons, Exterior Maintenance, Gym, Insurance, Lap Pool, Maintenance Grounds, Meeting Room, Pool, Recreation Facilities, Sewer, Tennis Court(s), Trash, Weight Room                                                                                1
# All Landscaping, Commons, Exterior Maintenance, Gym, Insurance, Maintenance Grounds, Management, Meeting Room, Party Room, Pool, Sewer, Spa/Hot Tub, Trash, Water, Weight Room                                                                                                                        1
# All Landscaping, Commons, Exterior Maintenance, Gym, Insurance, Management, Party Room, Pool, Sewer, Spa/Hot Tub, Trash, Water, Weight Room                                                                                                                                                           1
# Athletic Court, Basketball Court, Gym, Pool, Recreation Facilities, Sewer, Trash                                                                                                                                                                                                                      1
# All Landscaping, Exterior Maintenance, Gym, Lap Pool, Pool, Recreation Facilities, Sewer, Spa/Hot Tub, Trash, Water, Weight Room                                                                                                                                                                      1
# All Landscaping, Athletic Court, Basketball Court, Commons, Exterior Maintenance, Gym, Insurance, Lap Pool, Maintenance Grounds, Management, Meeting Room, Party Room, Pool, Recreation Facilities, Sauna, Sewer, Spa/Hot Tub, Trash, Water, Weight Room                                              1
# Athletic Court, Basketball Court, Commons, Exterior Maintenance, Gym, Lap Pool, Management, Meeting Room, Pool, Sewer, Spa/Hot Tub, Trash, Water, Weight Room                                                                                                                                         1
# Athletic Court, Basketball Court, Commons, Exterior Maintenance, Gym, Insurance, Lap Pool, Maintenance Grounds, Management, Pool, Recreation Facilities, Sauna, Sewer, Spa/Hot Tub, Trash, Water                                                                                                      1
# All Landscaping, Exterior Maintenance, Insurance, Maintenance Grounds, Management, Sewer, Trash, Water                                                                                                                                                                                                1
# All Landscaping, Athletic Court, Commons, Exterior Maintenance, Front Yard Landscaping, Gym, Maintenance Grounds, Management, Pool, Racquetball, Recreation Facilities, Sauna, Sewer, Spa/Hot Tub, Tennis Court(s), Trash, Water, Weight Room                                                         1
# Commons, Exterior Maintenance, Gym, Insurance, Laundry, Meeting Room, Pool, Sauna, Sewer, Water                                                                                                                                                                                                       1
# All Landscaping, Commons, Gym, Pool, Sewer, Trash, Water                                                                                                                                                                                                                                              1
# All Landscaping, Athletic Court, Commons, Exterior Maintenance, Gym, Insurance, Management, Pool, Recreation Facilities, Sewer, Spa/Hot Tub, Tennis Court(s), Trash, Water, Weight Room                                                                                                               1
# Athletic Court, Commons, Exterior Maintenance, Gym, Pool, Sewer, Tennis Court(s), Trash, Water, Weight Room                                                                                                                                                                                           1
# Athletic Court, Basketball Court, Commons, Exterior Maintenance, Gym, Lap Pool, Maintenance Grounds, Management, Meeting Room, Party Room, Pool, Recreation Facilities, Sewer, Spa/Hot Tub, Trash, Water, Weight Room                                                                                 1
# Basketball Court, Commons, Gym, Insurance, Management, Pool, Recreation Facilities, Sewer, Spa/Hot Tub, Tennis Court(s), Trash, Water, Weight Room                                                                                                                                                    1
# Commons, Exterior Maintenance, Gym, Lap Pool, Maintenance Grounds, Management, Meeting Room, Party Room, Pool, Road Maintenance, Sewer, Trash, Water                                                                                                                                                  1
# Commons, Exterior Maintenance, Management, Sewer, Water                                                                                                                                                                                                                                               1
# Athletic Court, Basketball Court, Commons, Exterior Maintenance, Lap Pool, Maintenance Grounds, Management, Pool, Recreation Facilities, Sewer, Tennis Court(s), Trash, Water                                                                                                                         1
# All Landscaping, Athletic Court, Commons, Exterior Maintenance, Front Yard Landscaping, Gym, Maintenance Grounds, Management, Meeting Room, Pool, Racquetball, Sauna, Sewer, Spa/Hot Tub, Tennis Court(s), Trash, Water, Weight Room                                                                  1
# All Landscaping, Basketball Court, Commons, Exterior Maintenance, Gym, Maintenance Grounds, Management, Pool, Sewer, Spa/Hot Tub, Tennis Court(s), Trash, Water                                                                                                                                       1
# Name: sewer, dtype: int64
#
# NULL COUNT
# ****************************
# 18
#
#
#
#
# cooling_yn
#
# VALUE COUNT
# ****************************
# Yes    104
# No      40
# Name: cooling_yn, dtype: int64
#
# NULL COUNT
# ****************************
# 19
#
#
#
#
# has_hoa
#
# VALUE COUNT
# ****************************
# Yes        92
# Has HOA     1
# Name: has_hoa, dtype: int64
#
# NULL COUNT
# ****************************
# 70
#
#
#
#
# senior_community_yn
#
# VALUE COUNT
# ****************************
# No     141
# Yes      2
# Name: senior_community_yn, dtype: int64
#
# NULL COUNT
# ****************************
# 20
#
#
#
#
# stories
#
# VALUE COUNT
# ****************************
# 1.0    87
# —      39
# 2.0    37
# Name: stories, dtype: int64
#
# NULL COUNT
# ****************************
# 0
#
#
#
#
# style
#
# VALUE COUNT
# ****************************
# Single Family Residential    107
# Condo/Co-op                   56
# Name: style, dtype: int64
#
# NULL COUNT
# ****************************
# 0
#
#
#
#
# yr_renovated
#
# VALUE COUNT
# ****************************
# —       124
# 1979     11
# 1978      7
# 1982      2
# 1985      2
# 1994      2
# 1971      2
# 1972      2
# 1981      2
# 1980      2
# 1958      1
# 1941      1
# 1984      1
# 1970      1
# 1997      1
# 1988      1
# 1990      1
# Name: yr_renovated, dtype: int64
#
# NULL COUNT
# ****************************
# 0
#
#
#
#
# county
#
# VALUE COUNT
# ****************************
# Clackamas County    124
# Multnomah County     39
# Name: county, dtype: int64
#
# NULL COUNT
# ****************************
# 0
#
#
#
#
# new_construction_yn
#
# VALUE COUNT
# ****************************
# No     139
# Yes      5
# Name: new_construction_yn, dtype: int64
#
# NULL COUNT
# ****************************
# 19

# %% [markdown]
# ## Dropping rows that seem too messy

# %%
dropped_columns = ['parking_features',
                   'parking_total',
                   'garage_type',
                   'garage_spaces',
                   'hot_water_desc',
                   'fireplace_yn',
                   'fireplace_total',
                   'basement',
                   'roof',
                   'lot_size',
                   'property_type',
                   'main_level_area',
                   'fuel_desc',
                   'sewer',
                   'stories',
                   'yr_renovated',
                   'lot_size_sqft']
df = df.drop(columns=dropped_columns)

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### I will clean view, cooling, senior community, new construction, and HOA features before converting them to dummy variables

# %%
features = ['view_yn', 'cooling_yn', 'senior_community_yn', 'new_construction_yn', 'has_hoa']

for feature in features:
    df[feature] = df[feature].fillna('No')
    df = df[df[feature].isin(['Yes', 'No'])]

# %%
df
# Out:
#                    Address                                               link  \
# 0    4965 SW Park Bluff Pl  https://www.redfin.com/OR/Lake-Oswego/4965-Par...
# 1          3569 Sunwood Ct  https://www.redfin.com/OR/Lake-Oswego/3569-Sun...
# 2          5225 Firwood Rd  https://www.redfin.com/OR/Lake-Oswego/5225-Fir...
# 4         3119 Douglas Cir  https://www.redfin.com/OR/Lake-Oswego/3119-Dou...
# 5       6338 Washington Ct  https://www.redfin.com/OR/Lake-Oswego/6338-Was...
# ..                     ...                                                ...
# 171      5254 Westfield Ct  https://www.redfin.com/OR/Lake-Oswego/5254-Wes...
# 172          4638 Lower Dr  https://www.redfin.com/OR/Lake-Oswego/4638-Low...
# 173      4324 Woodside Cir  https://www.redfin.com/OR/Lake-Oswego/4324-Woo...
# 174      110 Greenridge Ct  https://www.redfin.com/OR/Lake-Oswego/110-Gree...
# 175        4487 Westbay Rd  https://www.redfin.com/OR/Lake-Oswego/4487-Wes...
#
#        price beds baths  sqft view_yn yr_built cooling_yn has_hoa  \
# 0    2099000    5   4.5  4568     Yes     2022        Yes     Yes
# 1     700000    3   1.5  1350      No     1966         No      No
# 2    1550000    3   2.5  3240     Yes     1936        Yes      No
# 4    2675000    4     6  6524     Yes     1940        Yes      No
# 5     800000    2   1.5  1588     Yes     1958        Yes      No
# ..       ...  ...   ...   ...     ...      ...        ...     ...
# 171  1300000    4   2.5  3346     Yes     1988        Yes     Yes
# 172   307500    2   1.5  1260      No     1975         No     Yes
# 173   579000    2     2  1210     Yes     1979        Yes     Yes
# 174   527000    3   2.5  2868      No     1973         No     Yes
# 175  1200000    3     2  1869     Yes     1953        Yes     Yes
#
#     senior_community_yn                      style            county  \
# 0                    No  Single Family Residential  Clackamas County
# 1                    No  Single Family Residential  Clackamas County
# 2                    No  Single Family Residential  Clackamas County
# 4                    No  Single Family Residential  Clackamas County
# 5                    No  Single Family Residential  Clackamas County
# ..                  ...                        ...               ...
# 171                  No  Single Family Residential  Clackamas County
# 172                  No                Condo/Co-op  Clackamas County
# 173                  No  Single Family Residential  Clackamas County
# 174                  No  Single Family Residential  Clackamas County
# 175                  No  Single Family Residential  Clackamas County
#
#     new_construction_yn
# 0                   Yes
# 1                    No
# 2                    No
# 4                    No
# 5                    No
# ..                  ...
# 171                  No
# 172                  No
# 173                  No
# 174                  No
# 175                  No
#
# [162 rows x 14 columns]

# %%
df.to_csv(f'{zipcode}_homes_data_cleaned.csv', index=False)
