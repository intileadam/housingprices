# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
sns.set_theme()

# %%
zipcode = '97035'
filename = 'data/' + zipcode + '_homes_data_cleaned.csv'
df = pd.read_csv(filename)

# %%
df.describe(include='all')
# Out:
#                       Address  \
# count                     162
# unique                    162
# top     4965 SW Park Bluff Pl
# freq                        1
# mean                      NaN
# std                       NaN
# min                       NaN
# 25%                       NaN
# 50%                       NaN
# 75%                       NaN
# max                       NaN
#
#                                                      link         price  \
# count                                                 162  1.620000e+02
# unique                                                162           NaN
# top     https://www.redfin.com/OR/Lake-Oswego/4965-Par...           NaN
# freq                                                    1           NaN
# mean                                                  NaN  9.283610e+05
# std                                                   NaN  1.177257e+06
# min                                                   NaN  1.500000e+05
# 25%                                                   NaN  3.325000e+05
# 50%                                                   NaN  6.328445e+05
# 75%                                                   NaN  9.497500e+05
# max                                                   NaN  1.050000e+07
#
#               beds       baths         sqft view_yn     yr_built cooling_yn  \
# count   162.000000  162.000000   162.000000     162   162.000000        162
# unique         NaN         NaN          NaN       2          NaN          2
# top            NaN         NaN          NaN     Yes          NaN        Yes
# freq           NaN         NaN          NaN      90          NaN        104
# mean      3.061728    2.391975  2115.493827     NaN  1980.222222        NaN
# std       1.101616    0.988630  1321.639093     NaN    18.294689        NaN
# min       1.000000    1.000000   600.000000     NaN  1920.000000        NaN
# 25%       2.000000    2.000000  1178.500000     NaN  1970.000000        NaN
# 50%       3.000000    2.500000  1742.500000     NaN  1979.000000        NaN
# 75%       4.000000    2.500000  2706.750000     NaN  1988.000000        NaN
# max       6.000000    6.500000  8170.000000     NaN  2023.000000        NaN
#
#        has_hoa senior_community_yn                      style  \
# count      162                 162                        162
# unique       2                   2                          2
# top        Yes                  No  Single Family Residential
# freq        92                 160                        106
# mean       NaN                 NaN                        NaN
# std        NaN                 NaN                        NaN
# min        NaN                 NaN                        NaN
# 25%        NaN                 NaN                        NaN
# 50%        NaN                 NaN                        NaN
# 75%        NaN                 NaN                        NaN
# max        NaN                 NaN                        NaN
#
#                   county new_construction_yn
# count                162                 162
# unique                 2                   2
# top     Clackamas County                  No
# freq                 123                 157
# mean                 NaN                 NaN
# std                  NaN                 NaN
# min                  NaN                 NaN
# 25%                  NaN                 NaN
# 50%                  NaN                 NaN
# 75%                  NaN                 NaN
# max                  NaN                 NaN

# %%
df['log_price'] = np.log(df['price'])

# %%
df.isnull().sum()
# Out:
# Address                0
# link                   0
# price                  0
# beds                   0
# baths                  0
# sqft                   0
# view_yn                0
# yr_built               0
# cooling_yn             0
# has_hoa                0
# senior_community_yn    0
# style                  0
# county                 0
# new_construction_yn    0
# log_price              0
# dtype: int64

# %%
ax=sns.displot(df['log_price'])

# %%
q = df['log_price'].quantile(0.95)
df = df[df['log_price']<q]

# %%
ax=sns.displot(df['beds'])

# %%
ax=sns.displot(df['baths'])

# %%
ax=sns.displot(df['sqft'])

# %%
ax=sns.displot(df['yr_built'])

# %%
q = df['yr_built'].quantile(0.01)
df = df[df['yr_built']>q]

# %%
df = df.reset_index(drop=True)
df.describe(include='all')
# Out:
#                       Address  \
# count                     151
# unique                    151
# top     4965 SW Park Bluff Pl
# freq                        1
# mean                      NaN
# std                       NaN
# min                       NaN
# 25%                       NaN
# 50%                       NaN
# 75%                       NaN
# max                       NaN
#
#                                                      link         price  \
# count                                                 151  1.510000e+02
# unique                                                151           NaN
# top     https://www.redfin.com/OR/Lake-Oswego/4965-Par...           NaN
# freq                                                    1           NaN
# mean                                                  NaN  7.049048e+05
# std                                                   NaN  4.444198e+05
# min                                                   NaN  1.500000e+05
# 25%                                                   NaN  3.240000e+05
# 50%                                                   NaN  6.120940e+05
# 75%                                                   NaN  8.925000e+05
# max                                                   NaN  2.099000e+06
#
#               beds       baths         sqft view_yn     yr_built cooling_yn  \
# count   151.000000  151.000000   151.000000     151   151.000000        151
# unique         NaN         NaN          NaN       2          NaN          2
# top            NaN         NaN          NaN     Yes          NaN        Yes
# freq           NaN         NaN          NaN      83          NaN         94
# mean      2.973510    2.238411  1906.059603     NaN  1979.894040        NaN
# std       1.070495    0.754618   975.876169     NaN    15.440705        NaN
# min       1.000000    1.000000   600.000000     NaN  1941.000000        NaN
# 25%       2.000000    2.000000  1155.000000     NaN  1970.000000        NaN
# 50%       3.000000    2.000000  1619.000000     NaN  1979.000000        NaN
# 75%       4.000000    2.500000  2430.000000     NaN  1988.000000        NaN
# max       6.000000    4.500000  4571.000000     NaN  2023.000000        NaN
#
#        has_hoa senior_community_yn                      style  \
# count      151                 151                        151
# unique       2                   2                          2
# top        Yes                  No  Single Family Residential
# freq        89                 149                         95
# mean       NaN                 NaN                        NaN
# std        NaN                 NaN                        NaN
# min        NaN                 NaN                        NaN
# 25%        NaN                 NaN                        NaN
# 50%        NaN                 NaN                        NaN
# 75%        NaN                 NaN                        NaN
# max        NaN                 NaN                        NaN
#
#                   county new_construction_yn   log_price
# count                151                 151  151.000000
# unique                 2                   2         NaN
# top     Clackamas County                  No         NaN
# freq                 112                 149         NaN
# mean                 NaN                 NaN   13.274740
# std                  NaN                 NaN    0.629456
# min                  NaN                 NaN   11.918391
# 25%                  NaN                 NaN   12.688456
# 50%                  NaN                 NaN   13.324641
# 75%                  NaN                 NaN   13.701746
# max                  NaN                 NaN   14.556972

# %% [markdown]
# ## Checking OLS Assumptions

# %%
f, [[ax1, ax2], [ax3, ax4]] = plt.subplots(2, 2, sharey=True, figsize=(10, 10))
ax1.scatter(df['beds'], df['log_price'])
ax1.set_title('log_price and beds')
ax2.scatter(df['baths'], df['log_price'])
ax2.set_title('log_price and baths')
ax3.scatter(df['sqft'], df['log_price'])
ax3.set_title('log_price and sqft')
ax4.scatter(df['yr_built'], df['log_price'])
ax4.set_title('log_price and yr_built')

plt.show()

# %% [markdown]
# ## Checking for multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables = df[['beds', 'baths', 'sqft', 'yr_built']]
vif = pd.DataFrame()
vif['VIF'] = [variance_inflation_factor(variables.values, i) for i in range(variables.shape[1])]
vif["features"] = variables.columns

# %%
vif
# Out:
#          VIF  features
# 0  25.067148      beds
# 1  35.406859     baths
# 2  22.857024      sqft
# 3  13.949111  yr_built

# %% [markdown]
# ### I will want to think about how to reduce multicollinearity
# One idea is to search how people model home pricing on kaggle

# %% [markdown]
# ## Create Dummy variables

# %%
# Reorder columns
columns = ['Address', 'price', 'log_price', 'beds', 'baths', 'sqft', 'yr_built', 'view_yn', 'cooling_yn', 'senior_community_yn', 'style', 'county', 'new_construction_yn', 'has_hoa']
df = df[columns]

# %%
df = pd.get_dummies(df, columns=df.columns[7:], drop_first=True)

# %%
df.head()
# Out:
#                  Address    price  log_price  beds  baths  sqft  yr_built  \
# 0  4965 SW Park Bluff Pl  2099000  14.556972     5    4.5  4568      2022
# 1        3569 Sunwood Ct   700000  13.458836     3    1.5  1350      1966
# 2     6338 Washington Ct   800000  13.592367     2    1.5  1588      1958
# 3       4672 Winthrop Ct  1790000  14.397726     5    3.5  4161      2020
# 4       16900 Gassner Ln  1622500  14.299479     4    3.5  3953      1973
#
#    view_yn_Yes  cooling_yn_Yes  senior_community_yn_Yes  \
# 0            1               1                        0
# 1            0               0                        0
# 2            1               1                        0
# 3            0               1                        0
# 4            0               1                        0
#
#    style_Single Family Residential  county_Multnomah County  \
# 0                                1                        0
# 1                                1                        0
# 2                                1                        0
# 3                                1                        0
# 4                                1                        0
#
#    new_construction_yn_Yes  has_hoa_Yes
# 0                        1            1
# 1                        0            0
# 2                        0            0
# 3                        0            1
# 4                        0            0

# %% [markdown]
# ## Linear Regression Model

# %%
targets = df['log_price']
inputs = df.drop(['Address', 'price', 'log_price', 'senior_community_yn_Yes', 'new_construction_yn_Yes', 'view_yn_Yes'], axis=1)

# %% [markdown]
# ### Scale the data

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(inputs)
# Out:
# StandardScaler()

# %%
inputs_scaled = scaler.transform(inputs)

# %%
inputs_scaled
# Out:
# array([[ 1.89933925,  3.00697295,  2.73682141, ...,  0.7677719 ,
#         -0.59009684,  0.83464317],
#        [ 0.02482796, -0.98177887, -0.57170169, ...,  0.7677719 ,
#         -0.59009684, -1.1981168 ],
#        [-0.91242768, -0.98177887, -0.32700669, ...,  0.7677719 ,
#         -0.59009684, -1.1981168 ],
#        ...,
#        [-0.91242768, -0.3169869 , -0.71563992, ...,  0.7677719 ,
#         -0.59009684,  0.83464317],
#        [ 0.02482796,  0.34780507,  0.98900001, ...,  0.7677719 ,
#         -0.59009684,  0.83464317],
#        [ 0.02482796, -0.3169869 , -0.0381021 , ...,  0.7677719 ,
#         -0.59009684,  0.83464317]])

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(inputs_scaled, targets, test_size=0.2, random_state=47)

# %% [markdown]
# ### Regression

# %%
reg = LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_hat = reg.predict(x_train)
plt.scatter(y_train, y_hat)

# %%
sns.displot(y_train - y_hat)
plt.title("Residuals PDF")
# Out:
# Text(0.5, 1.0, 'Residuals PDF')

# %%
reg.score(x_train, y_train)
# Out:
# 0.9297132901746926

# %%
def adj_r2(x,y):
    r2 = reg.score(x,y)
    n = x.shape[0]
    p = x.shape[1]
    adjusted_r2 = 1-(1-r2)*(n-1)/(n-p-1)
    return adjusted_r2

# %%
adj_r2(x_train, y_train)
# Out:
# 0.9246475813584543

# %%
adj_r2(x_test, y_test)
# Out:
# 0.8306080720775787

# %%
reg_summary = pd.DataFrame(inputs.columns.values, columns=['Features'])
reg_summary['Weights'] = (np.exp(reg.coef_ / scaler.scale_) - 1) * 100

# %%
from sklearn.feature_selection import f_regression
f_stat, p_values = f_regression(x_train, y_train)

# %%
reg_summary['f_stat'] = f_stat.round(3)
reg_summary['p_value'] = p_values.round(3)
reg_summary
# Out:
#                           Features    Weights   f_stat  p_value
# 0                             beds   3.876805  261.238      0.0
# 1                            baths   0.614632   95.803      0.0
# 2                             sqft   0.030396  343.884      0.0
# 3                         yr_built   0.355555   15.658      0.0
# 4                   cooling_yn_Yes   5.832327   22.850      0.0
# 5  style_Single Family Residential  76.773329  280.279      0.0
# 6          county_Multnomah County -11.238512   23.019      0.0
# 7                      has_hoa_Yes  -7.834059   15.274      0.0

# %%
y_hat_test = reg.predict(x_test)

# %%
plt.scatter(y_test, y_hat_test)

# %%
df_pf = pd.DataFrame(y_hat_test, columns=['log_predictions'])
df_pf['predictions'] = np.exp(y_hat_test)

# %%
y_test = y_test.reset_index(drop=True)
df_pf['log_target'] = y_test
df_pf['target'] = np.exp(y_test)
df_pf
# Out:
#     log_predictions   predictions  log_target     target
# 0         13.641309  8.401272e+05   13.560618   775000.0
# 1         14.557018  2.099097e+06   14.556972  2099000.0
# 2         13.674619  8.685832e+05   13.573439   785000.0
# 3         12.418231  2.472687e+05   12.506177   270000.0
# 4         13.453339  6.961626e+05   13.304685   600000.0
# 5         12.655489  3.134793e+05   12.706848   330000.0
# 6         12.475443  2.618279e+05   12.506177   270000.0
# 7         13.573516  7.850607e+05   13.311329   604000.0
# 8         12.546344  2.810657e+05   12.581079   291000.0
# 9         12.594948  2.950642e+05   12.628067   305000.0
# 10        12.371738  2.360357e+05   11.918391   150000.0
# 11        14.420100  1.830501e+06   14.397726  1790000.0
# 12        13.822237  1.006749e+06   13.681979   875000.0
# 13        13.513583  7.393913e+05   13.623017   824900.0
# 14        13.347929  6.265159e+05   13.324488   612000.0
# 15        12.505904  2.699262e+05   12.538967   279000.0
# 16        13.376584  6.447280e+05   13.429848   680000.0
# 17        13.310719  6.036316e+05   13.458836   700000.0
# 18        12.339472  2.285412e+05   12.301383   220000.0
# 19        12.999819  4.423333e+05   13.017003   450000.0
# 20        12.502181  2.689231e+05   12.524526   275000.0
# 21        12.527436  2.758013e+05   12.487485   265000.0
# 22        14.016762  1.222933e+06   13.910821  1100000.0
# 23        13.285313  5.884888e+05   13.321214   610000.0
# 24        13.140977  5.093941e+05   13.976779  1175000.0
# 25        13.320733  6.097065e+05   13.400071   660050.0
# 26        13.721447  9.102247e+05   13.174956   527000.0
# 27        13.464797  7.041852e+05   13.345507   625000.0
# 28        13.688415  8.806491e+05   13.681979   875000.0
# 29        12.686104  3.232250e+05   12.793859   360000.0
# 30        13.419818  6.732135e+05   13.384728   650000.0

# %%
df_pf['residual'] = df_pf['target'] - df_pf['predictions']
df_pf['Difference%'] = df_pf['residual']/df_pf['target']*100
df_pf
# Out:
#     log_predictions   predictions  log_target     target       residual  \
# 0         13.641309  8.401272e+05   13.560618   775000.0  -65127.162858
# 1         14.557018  2.099097e+06   14.556972  2099000.0     -96.547365
# 2         13.674619  8.685832e+05   13.573439   785000.0  -83583.225448
# 3         12.418231  2.472687e+05   12.506177   270000.0   22731.254624
# 4         13.453339  6.961626e+05   13.304685   600000.0  -96162.597102
# 5         12.655489  3.134793e+05   12.706848   330000.0   16520.727810
# 6         12.475443  2.618279e+05   12.506177   270000.0    8172.066291
# 7         13.573516  7.850607e+05   13.311329   604000.0 -181060.725097
# 8         12.546344  2.810657e+05   12.581079   291000.0    9934.295219
# 9         12.594948  2.950642e+05   12.628067   305000.0    9935.788554
# 10        12.371738  2.360357e+05   11.918391   150000.0  -86035.677266
# 11        14.420100  1.830501e+06   14.397726  1790000.0  -40501.252120
# 12        13.822237  1.006749e+06   13.681979   875000.0 -131749.160572
# 13        13.513583  7.393913e+05   13.623017   824900.0   85508.661144
# 14        13.347929  6.265159e+05   13.324488   612000.0  -14515.930750
# 15        12.505904  2.699262e+05   12.538967   279000.0    9073.758869
# 16        13.376584  6.447280e+05   13.429848   680000.0   35272.020646
# 17        13.310719  6.036316e+05   13.458836   700000.0   96368.441140
# 18        12.339472  2.285412e+05   12.301383   220000.0   -8541.188971
# 19        12.999819  4.423333e+05   13.017003   450000.0    7666.700390
# 20        12.502181  2.689231e+05   12.524526   275000.0    6076.888348
# 21        12.527436  2.758013e+05   12.487485   265000.0  -10801.318836
# 22        14.016762  1.222933e+06   13.910821  1100000.0 -122932.744909
# 23        13.285313  5.884888e+05   13.321214   610000.0   21511.174335
# 24        13.140977  5.093941e+05   13.976779  1175000.0  665605.925020
# 25        13.320733  6.097065e+05   13.400071   660050.0   50343.528591
# 26        13.721447  9.102247e+05   13.174956   527000.0 -383224.653370
# 27        13.464797  7.041852e+05   13.345507   625000.0  -79185.186152
# 28        13.688415  8.806491e+05   13.681979   875000.0   -5649.102050
# 29        12.686104  3.232250e+05   12.793859   360000.0   36775.039553
# 30        13.419818  6.732135e+05   13.384728   650000.0  -23213.501112
#
#     Difference%
# 0     -8.403505
# 1     -0.004600
# 2    -10.647545
# 3      8.418983
# 4    -16.027100
# 5      5.006281
# 6      3.026691
# 7    -29.976941
# 8      3.413847
# 9      3.257636
# 10   -57.357118
# 11    -2.262640
# 12   -15.057047
# 13    10.365943
# 14    -2.371884
# 15     3.252243
# 16     5.187062
# 17    13.766920
# 18    -3.882359
# 19     1.703711
# 20     2.209778
# 21    -4.075969
# 22   -11.175704
# 23     3.526422
# 24    56.647313
# 25     7.627230
# 26   -72.718151
# 27   -12.669630
# 28    -0.645612
# 29    10.215289
# 30    -3.571308

# %%
import scipy.stats as stats
SE_residual = np.sqrt(np.sum(df_pf['residual']**2) / (len(y_test) - x_test.shape[1]))
margin_error = SE_residual*stats.t.ppf(.90, len(x_test) - 1)
df_pf['lower_bound'] = df_pf['predictions'] - margin_error
df_pf['upper_bound'] = df_pf['predictions'] + margin_error
df_pf
# Out:
#     log_predictions   predictions  log_target     target       residual  \
# 0         13.641309  8.401272e+05   13.560618   775000.0  -65127.162858
# 1         14.557018  2.099097e+06   14.556972  2099000.0     -96.547365
# 2         13.674619  8.685832e+05   13.573439   785000.0  -83583.225448
# 3         12.418231  2.472687e+05   12.506177   270000.0   22731.254624
# 4         13.453339  6.961626e+05   13.304685   600000.0  -96162.597102
# 5         12.655489  3.134793e+05   12.706848   330000.0   16520.727810
# 6         12.475443  2.618279e+05   12.506177   270000.0    8172.066291
# 7         13.573516  7.850607e+05   13.311329   604000.0 -181060.725097
# 8         12.546344  2.810657e+05   12.581079   291000.0    9934.295219
# 9         12.594948  2.950642e+05   12.628067   305000.0    9935.788554
# 10        12.371738  2.360357e+05   11.918391   150000.0  -86035.677266
# 11        14.420100  1.830501e+06   14.397726  1790000.0  -40501.252120
# 12        13.822237  1.006749e+06   13.681979   875000.0 -131749.160572
# 13        13.513583  7.393913e+05   13.623017   824900.0   85508.661144
# 14        13.347929  6.265159e+05   13.324488   612000.0  -14515.930750
# 15        12.505904  2.699262e+05   12.538967   279000.0    9073.758869
# 16        13.376584  6.447280e+05   13.429848   680000.0   35272.020646
# 17        13.310719  6.036316e+05   13.458836   700000.0   96368.441140
# 18        12.339472  2.285412e+05   12.301383   220000.0   -8541.188971
# 19        12.999819  4.423333e+05   13.017003   450000.0    7666.700390
# 20        12.502181  2.689231e+05   12.524526   275000.0    6076.888348
# 21        12.527436  2.758013e+05   12.487485   265000.0  -10801.318836
# 22        14.016762  1.222933e+06   13.910821  1100000.0 -122932.744909
# 23        13.285313  5.884888e+05   13.321214   610000.0   21511.174335
# 24        13.140977  5.093941e+05   13.976779  1175000.0  665605.925020
# 25        13.320733  6.097065e+05   13.400071   660050.0   50343.528591
# 26        13.721447  9.102247e+05   13.174956   527000.0 -383224.653370
# 27        13.464797  7.041852e+05   13.345507   625000.0  -79185.186152
# 28        13.688415  8.806491e+05   13.681979   875000.0   -5649.102050
# 29        12.686104  3.232250e+05   12.793859   360000.0   36775.039553
# 30        13.419818  6.732135e+05   13.384728   650000.0  -23213.501112
#
#     Difference%   lower_bound   upper_bound
# 0     -8.403505  6.090283e+05  1.071226e+06
# 1     -0.004600  1.867998e+06  2.330195e+06
# 2    -10.647545  6.374844e+05  1.099682e+06
# 3      8.418983  1.616990e+04  4.783676e+05
# 4    -16.027100  4.650637e+05  9.272614e+05
# 5      5.006281  8.238042e+04  5.445781e+05
# 6      3.026691  3.072909e+04  4.929268e+05
# 7    -29.976941  5.539619e+05  1.016160e+06
# 8      3.413847  4.996686e+04  5.121646e+05
# 9      3.257636  6.396536e+04  5.261631e+05
# 10   -57.357118  4.936830e+03  4.671345e+05
# 11    -2.262640  1.599402e+06  2.061600e+06
# 12   -15.057047  7.756503e+05  1.237848e+06
# 13    10.365943  5.082925e+05  9.704902e+05
# 14    -2.371884  3.954171e+05  8.576148e+05
# 15     3.252243  3.882739e+04  5.010251e+05
# 16     5.187062  4.136291e+05  8.758268e+05
# 17    13.766920  3.725327e+05  8.347304e+05
# 18    -3.882359 -2.557658e+03  4.596400e+05
# 19     1.703711  2.112345e+05  6.734321e+05
# 20     2.209778  3.782426e+04  5.000220e+05
# 21    -4.075969  4.470247e+04  5.069002e+05
# 22   -11.175704  9.918339e+05  1.454032e+06
# 23     3.526422  3.573900e+05  8.195877e+05
# 24    56.647313  2.782952e+05  7.404929e+05
# 25     7.627230  3.786076e+05  8.408053e+05
# 26   -72.718151  6.791258e+05  1.141324e+06
# 27   -12.669630  4.730863e+05  9.352840e+05
# 28    -0.645612  6.495503e+05  1.111748e+06
# 29    10.215289  9.212611e+04  5.543238e+05
# 30    -3.571308  4.421147e+05  9.043123e+05
