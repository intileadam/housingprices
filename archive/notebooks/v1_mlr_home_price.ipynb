# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
sns.set_theme()

# %%
zipcode = '97035'
filename = 'data/' + zipcode + '_homes_data_cleaned.csv'
df = pd.read_csv(filename)

# %%
df.describe(include='all')
# Out:
#                       Address  \
# count                     162
# unique                    162
# top     4965 SW Park Bluff Pl
# freq                        1
# mean                      NaN
# std                       NaN
# min                       NaN
# 25%                       NaN
# 50%                       NaN
# 75%                       NaN
# max                       NaN
#
#                                                      link         price  \
# count                                                 162  1.620000e+02
# unique                                                162           NaN
# top     https://www.redfin.com/OR/Lake-Oswego/4965-Par...           NaN
# freq                                                    1           NaN
# mean                                                  NaN  9.283610e+05
# std                                                   NaN  1.177257e+06
# min                                                   NaN  1.500000e+05
# 25%                                                   NaN  3.325000e+05
# 50%                                                   NaN  6.328445e+05
# 75%                                                   NaN  9.497500e+05
# max                                                   NaN  1.050000e+07
#
#               beds       baths         sqft view_yn     yr_built cooling_yn  \
# count   162.000000  162.000000   162.000000     162   162.000000        162
# unique         NaN         NaN          NaN       2          NaN          2
# top            NaN         NaN          NaN     Yes          NaN        Yes
# freq           NaN         NaN          NaN      90          NaN        104
# mean      3.061728    2.391975  2115.493827     NaN  1980.222222        NaN
# std       1.101616    0.988630  1321.639093     NaN    18.294689        NaN
# min       1.000000    1.000000   600.000000     NaN  1920.000000        NaN
# 25%       2.000000    2.000000  1178.500000     NaN  1970.000000        NaN
# 50%       3.000000    2.500000  1742.500000     NaN  1979.000000        NaN
# 75%       4.000000    2.500000  2706.750000     NaN  1988.000000        NaN
# max       6.000000    6.500000  8170.000000     NaN  2023.000000        NaN
#
#        has_hoa senior_community_yn                      style  \
# count      162                 162                        162
# unique       2                   2                          2
# top        Yes                  No  Single Family Residential
# freq        92                 160                        106
# mean       NaN                 NaN                        NaN
# std        NaN                 NaN                        NaN
# min        NaN                 NaN                        NaN
# 25%        NaN                 NaN                        NaN
# 50%        NaN                 NaN                        NaN
# 75%        NaN                 NaN                        NaN
# max        NaN                 NaN                        NaN
#
#                   county new_construction_yn
# count                162                 162
# unique                 2                   2
# top     Clackamas County                  No
# freq                 123                 157
# mean                 NaN                 NaN
# std                  NaN                 NaN
# min                  NaN                 NaN
# 25%                  NaN                 NaN
# 50%                  NaN                 NaN
# 75%                  NaN                 NaN
# max                  NaN                 NaN

# %%
df.isnull().sum()
# Out:
# Address                0
# link                   0
# price                  0
# beds                   0
# baths                  0
# sqft                   0
# view_yn                0
# yr_built               0
# cooling_yn             0
# has_hoa                0
# senior_community_yn    0
# style                  0
# county                 0
# new_construction_yn    0
# dtype: int64

# %%
ax=sns.displot(df['price'])

# %%
q = df['price'].quantile(0.95)
df = df[df['price']<q]

# %%
ax=sns.displot(df['beds'])

# %%
ax=sns.displot(df['baths'])

# %%
ax=sns.displot(df['sqft'])

# %%
ax=sns.displot(df['yr_built'])

# %%
q = df['yr_built'].quantile(0.01)
df = df[df['yr_built']>q]

# %%
df = df.reset_index(drop=True)
df.describe(include='all')
# Out:
#                       Address  \
# count                     151
# unique                    151
# top     4965 SW Park Bluff Pl
# freq                        1
# mean                      NaN
# std                       NaN
# min                       NaN
# 25%                       NaN
# 50%                       NaN
# 75%                       NaN
# max                       NaN
#
#                                                      link         price  \
# count                                                 151  1.510000e+02
# unique                                                151           NaN
# top     https://www.redfin.com/OR/Lake-Oswego/4965-Par...           NaN
# freq                                                    1           NaN
# mean                                                  NaN  7.049048e+05
# std                                                   NaN  4.444198e+05
# min                                                   NaN  1.500000e+05
# 25%                                                   NaN  3.240000e+05
# 50%                                                   NaN  6.120940e+05
# 75%                                                   NaN  8.925000e+05
# max                                                   NaN  2.099000e+06
#
#               beds       baths         sqft view_yn     yr_built cooling_yn  \
# count   151.000000  151.000000   151.000000     151   151.000000        151
# unique         NaN         NaN          NaN       2          NaN          2
# top            NaN         NaN          NaN     Yes          NaN        Yes
# freq           NaN         NaN          NaN      83          NaN         94
# mean      2.973510    2.238411  1906.059603     NaN  1979.894040        NaN
# std       1.070495    0.754618   975.876169     NaN    15.440705        NaN
# min       1.000000    1.000000   600.000000     NaN  1941.000000        NaN
# 25%       2.000000    2.000000  1155.000000     NaN  1970.000000        NaN
# 50%       3.000000    2.000000  1619.000000     NaN  1979.000000        NaN
# 75%       4.000000    2.500000  2430.000000     NaN  1988.000000        NaN
# max       6.000000    4.500000  4571.000000     NaN  2023.000000        NaN
#
#        has_hoa senior_community_yn                      style  \
# count      151                 151                        151
# unique       2                   2                          2
# top        Yes                  No  Single Family Residential
# freq        89                 149                         95
# mean       NaN                 NaN                        NaN
# std        NaN                 NaN                        NaN
# min        NaN                 NaN                        NaN
# 25%        NaN                 NaN                        NaN
# 50%        NaN                 NaN                        NaN
# 75%        NaN                 NaN                        NaN
# max        NaN                 NaN                        NaN
#
#                   county new_construction_yn
# count                151                 151
# unique                 2                   2
# top     Clackamas County                  No
# freq                 112                 149
# mean                 NaN                 NaN
# std                  NaN                 NaN
# min                  NaN                 NaN
# 25%                  NaN                 NaN
# 50%                  NaN                 NaN
# 75%                  NaN                 NaN
# max                  NaN                 NaN

# %% [markdown]
# ## Checking OLS Assumptions

# %%
f, [[ax1, ax2], [ax3, ax4]] = plt.subplots(2, 2, sharey=True, figsize=(10, 10))
ax1.scatter(df['beds'], df['price'])
ax1.set_title('price and beds')
ax2.scatter(df['baths'], df['price'])
ax2.set_title('price and baths')
ax3.scatter(df['sqft'], df['price'])
ax3.set_title('price and sqft')
ax4.scatter(df['yr_built'], df['price'])
ax4.set_title('price and yr_built')

plt.show()

# %% [markdown]
# ### Relationships look fairly linear, so no transformation of price at this time

# %% [markdown]
# ## Checking for multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables = df[['beds', 'baths', 'sqft', 'yr_built']]
vif = pd.DataFrame()
vif['VIF'] = [variance_inflation_factor(variables.values, i) for i in range(variables.shape[1])]
vif["features"] = variables.columns

# %%
vif
# Out:
#          VIF  features
# 0  25.067148      beds
# 1  35.406859     baths
# 2  22.857024      sqft
# 3  13.949111  yr_built

# %% [markdown]
# ### I will want to think about how to reduce multicollinearity
# One idea is to search how people model home pricing on kaggle

# %% [markdown]
# ## Create Dummy variables

# %%
# Reorder columns
columns = ['Address', 'price', 'beds', 'baths', 'sqft', 'yr_built', 'view_yn', 'cooling_yn', 'senior_community_yn', 'style', 'county', 'new_construction_yn', 'has_hoa']
df = df[columns]

# %%
df = pd.get_dummies(df, columns=df.columns[6:], drop_first=True)

# %%
df.head()
# Out:
#                  Address    price  beds  baths  sqft  yr_built  view_yn_Yes  \
# 0  4965 SW Park Bluff Pl  2099000     5    4.5  4568      2022            1
# 1        3569 Sunwood Ct   700000     3    1.5  1350      1966            0
# 2     6338 Washington Ct   800000     2    1.5  1588      1958            1
# 3       4672 Winthrop Ct  1790000     5    3.5  4161      2020            0
# 4       16900 Gassner Ln  1622500     4    3.5  3953      1973            0
#
#    cooling_yn_Yes  senior_community_yn_Yes  style_Single Family Residential  \
# 0               1                        0                                1
# 1               0                        0                                1
# 2               1                        0                                1
# 3               1                        0                                1
# 4               1                        0                                1
#
#    county_Multnomah County  new_construction_yn_Yes  has_hoa_Yes
# 0                        0                        1            1
# 1                        0                        0            0
# 2                        0                        0            0
# 3                        0                        0            1
# 4                        0                        0            0

# %% [markdown]
# ## Linear Regression Model

# %%
targets = df['price']
inputs = df.drop(['Address', 'price', 'senior_community_yn_Yes', 'new_construction_yn_Yes', 'view_yn_Yes'], axis=1)

# %% [markdown]
# ### Scale the data

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(inputs)
# Out:
# StandardScaler()

# %%
inputs_scaled = scaler.transform(inputs)

# %%
inputs_scaled
# Out:
# array([[ 1.89933925,  3.00697295,  2.73682141, ...,  0.7677719 ,
#         -0.59009684,  0.83464317],
#        [ 0.02482796, -0.98177887, -0.57170169, ...,  0.7677719 ,
#         -0.59009684, -1.1981168 ],
#        [-0.91242768, -0.98177887, -0.32700669, ...,  0.7677719 ,
#         -0.59009684, -1.1981168 ],
#        ...,
#        [-0.91242768, -0.3169869 , -0.71563992, ...,  0.7677719 ,
#         -0.59009684,  0.83464317],
#        [ 0.02482796,  0.34780507,  0.98900001, ...,  0.7677719 ,
#         -0.59009684,  0.83464317],
#        [ 0.02482796, -0.3169869 , -0.0381021 , ...,  0.7677719 ,
#         -0.59009684,  0.83464317]])

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(inputs_scaled, targets, test_size=0.2, random_state=47)

# %% [markdown]
# ### Regression

# %%
reg = LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_hat = reg.predict(x_train)
plt.scatter(y_train, y_hat)

# %%
sns.displot(y_train - y_hat)
plt.title("Residuals PDF")
# Out:
# Text(0.5, 1.0, 'Residuals PDF')

# %%
def adj_r2(x,y):
    r2 = reg.score(x,y)
    n = x.shape[0]
    p = x.shape[1]
    adjusted_r2 = 1-(1-r2)*(n-1)/(n-p-1)
    return adjusted_r2

# %%
adj_r2(x_train, y_train)
# Out:
# 0.8815983229064018

# %%
adj_r2(x_test, y_test)
# Out:
# 0.8052972727375639

# %%
reg_summary = pd.DataFrame(inputs.columns.values, columns=['Features'])
reg_summary['Weights'] = reg.coef_

# %%
from sklearn.feature_selection import f_regression
f_stat, p_values = f_regression(x_train, y_train)

# %%
reg_summary['f_stat'] = f_stat.round(3)
reg_summary['p_value'] = p_values.round(3)
reg_summary
# Out:
#                           Features        Weights   f_stat  p_value
# 0                             beds    4694.576237  189.543      0.0
# 1                            baths  -42447.226089  111.918      0.0
# 2                             sqft  332727.159423  472.070      0.0
# 3                         yr_built   63252.072117   27.526      0.0
# 4                   cooling_yn_Yes   30122.548464   20.129      0.0
# 5  style_Single Family Residential   64669.363325  112.542      0.0
# 6          county_Multnomah County  -55529.646658   19.059      0.0
# 7                      has_hoa_Yes  -59726.579601   13.286      0.0

# %%
y_hat_test = reg.predict(x_test)

# %%
plt.scatter(y_test, y_hat_test)

# %%
df_pf = pd.DataFrame(y_hat_test, columns=['Predictions'])

# %%
y_test = y_test.reset_index(drop=True)
df_pf['Target'] = y_test
df_pf
# Out:
#      Predictions   Target
# 0   8.992765e+05   775000
# 1   1.727786e+06  2099000
# 2   8.566672e+05   785000
# 3   1.686639e+05   270000
# 4   7.438837e+05   600000
# 5   3.707241e+05   330000
# 6   1.930376e+05   270000
# 7   8.402849e+05   604000
# 8   2.432476e+05   291000
# 9   3.587051e+05   305000
# 10  1.463863e+05   150000
# 11  1.636774e+06  1790000
# 12  1.091687e+06   875000
# 13  7.129527e+05   824900
# 14  6.270154e+05   612000
# 15  2.039010e+05   279000
# 16  6.588093e+05   680000
# 17  6.165681e+05   700000
# 18  1.184243e+05   220000
# 19  7.190893e+05   450000
# 20  2.952848e+05   275000
# 21  2.198950e+05   265000
# 22  1.250320e+06  1100000
# 23  5.561883e+05   610000
# 24  8.458968e+05  1175000
# 25  5.582189e+05   660050
# 26  9.867796e+05   527000
# 27  7.281611e+05   625000
# 28  9.522999e+05   875000
# 29  3.769101e+05   360000
# 30  6.155370e+05   650000

# %%
df_pf['Residual'] = df_pf['Target'] - df_pf['Predictions']
df_pf['Difference%'] = df_pf['Residual']/df_pf['Target']*100
df_pf
# Out:
#      Predictions   Target       Residual  Difference%
# 0   8.992765e+05   775000 -124276.480627   -16.035675
# 1   1.727786e+06  2099000  371213.584858    17.685259
# 2   8.566672e+05   785000  -71667.152593    -9.129574
# 3   1.686639e+05   270000  101336.076633    37.531880
# 4   7.438837e+05   600000 -143883.721923   -23.980620
# 5   3.707241e+05   330000  -40724.062557   -12.340625
# 6   1.930376e+05   270000   76962.388147    28.504588
# 7   8.402849e+05   604000 -236284.944633   -39.120024
# 8   2.432476e+05   291000   47752.358921    16.409745
# 9   3.587051e+05   305000  -53705.127425   -17.608238
# 10  1.463863e+05   150000    3613.722902     2.409149
# 11  1.636774e+06  1790000  153225.947863     8.560109
# 12  1.091687e+06   875000 -216687.400989   -24.764274
# 13  7.129527e+05   824900  111947.308364    13.571016
# 14  6.270154e+05   612000  -15015.429515    -2.453502
# 15  2.039010e+05   279000   75098.989851    26.917201
# 16  6.588093e+05   680000   21190.652011     3.116272
# 17  6.165681e+05   700000   83431.889254    11.918841
# 18  1.184243e+05   220000  101575.733036    46.170788
# 19  7.190893e+05   450000 -269089.279031   -59.797618
# 20  2.952848e+05   275000  -20284.773154    -7.376281
# 21  2.198950e+05   265000   45104.979860    17.020747
# 22  1.250320e+06  1100000 -150319.598379   -13.665418
# 23  5.561883e+05   610000   53811.668247     8.821585
# 24  8.458968e+05  1175000  329103.168018    28.008780
# 25  5.582189e+05   660050  101831.059553    15.427780
# 26  9.867796e+05   527000 -459779.577421   -87.244702
# 27  7.281611e+05   625000 -103161.121839   -16.505779
# 28  9.522999e+05   875000  -77299.942870    -8.834279
# 29  3.769101e+05   360000  -16910.140230    -4.697261
# 30  6.155370e+05   650000   34463.029129     5.302004
