# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
sns.set_theme()

# %%
zipcode = '97035'
filename = 'data/' + zipcode + '_homes_data_cleaned.csv'
df = pd.read_csv(filename)

# %%
df.describe(include='all')
# Out:
#                       Address  \
# count                     162
# unique                    162
# top     4965 SW Park Bluff Pl
# freq                        1
# mean                      NaN
# std                       NaN
# min                       NaN
# 25%                       NaN
# 50%                       NaN
# 75%                       NaN
# max                       NaN
#
#                                                      link         price  \
# count                                                 162  1.620000e+02
# unique                                                162           NaN
# top     https://www.redfin.com/OR/Lake-Oswego/4965-Par...           NaN
# freq                                                    1           NaN
# mean                                                  NaN  9.283610e+05
# std                                                   NaN  1.177257e+06
# min                                                   NaN  1.500000e+05
# 25%                                                   NaN  3.325000e+05
# 50%                                                   NaN  6.328445e+05
# 75%                                                   NaN  9.497500e+05
# max                                                   NaN  1.050000e+07
#
#               beds       baths         sqft view_yn     yr_built cooling_yn  \
# count   162.000000  162.000000   162.000000     162   162.000000        162
# unique         NaN         NaN          NaN       2          NaN          2
# top            NaN         NaN          NaN     Yes          NaN        Yes
# freq           NaN         NaN          NaN      90          NaN        104
# mean      3.061728    2.391975  2115.493827     NaN  1980.222222        NaN
# std       1.101616    0.988630  1321.639093     NaN    18.294689        NaN
# min       1.000000    1.000000   600.000000     NaN  1920.000000        NaN
# 25%       2.000000    2.000000  1178.500000     NaN  1970.000000        NaN
# 50%       3.000000    2.500000  1742.500000     NaN  1979.000000        NaN
# 75%       4.000000    2.500000  2706.750000     NaN  1988.000000        NaN
# max       6.000000    6.500000  8170.000000     NaN  2023.000000        NaN
#
#        has_hoa senior_community_yn                      style  \
# count      162                 162                        162
# unique       2                   2                          2
# top        Yes                  No  Single Family Residential
# freq        92                 160                        106
# mean       NaN                 NaN                        NaN
# std        NaN                 NaN                        NaN
# min        NaN                 NaN                        NaN
# 25%        NaN                 NaN                        NaN
# 50%        NaN                 NaN                        NaN
# 75%        NaN                 NaN                        NaN
# max        NaN                 NaN                        NaN
#
#                   county new_construction_yn
# count                162                 162
# unique                 2                   2
# top     Clackamas County                  No
# freq                 123                 157
# mean                 NaN                 NaN
# std                  NaN                 NaN
# min                  NaN                 NaN
# 25%                  NaN                 NaN
# 50%                  NaN                 NaN
# 75%                  NaN                 NaN
# max                  NaN                 NaN

# %%
df['log_price'] = np.log(df['price'])

# %%
df.isnull().sum()
# Out:
# Address                0
# link                   0
# price                  0
# beds                   0
# baths                  0
# sqft                   0
# view_yn                0
# yr_built               0
# cooling_yn             0
# has_hoa                0
# senior_community_yn    0
# style                  0
# county                 0
# new_construction_yn    0
# log_price              0
# dtype: int64

# %%
ax=sns.displot(df['price'])

# %%
q = df['price'].quantile(0.95)
df = df[df['price']<q]

# %%
ax=sns.displot(df['beds'])

# %%
ax=sns.displot(df['baths'])

# %%
ax=sns.displot(np.sqrt(df['sqft']))

# %%
df['sqft'] = np.sqrt(df['sqft'])

# %%
ax=sns.displot(df['sqft'])

# %%
ax=sns.displot(df['yr_built'])

# %%
q = df['yr_built'].quantile(0.01)
df = df[df['yr_built']>q]

# %%
df = df.reset_index(drop=True)
df.describe(include='all')
# Out:
#                       Address  \
# count                     151
# unique                    151
# top     4965 SW Park Bluff Pl
# freq                        1
# mean                      NaN
# std                       NaN
# min                       NaN
# 25%                       NaN
# 50%                       NaN
# 75%                       NaN
# max                       NaN
#
#                                                      link         price  \
# count                                                 151  1.510000e+02
# unique                                                151           NaN
# top     https://www.redfin.com/OR/Lake-Oswego/4965-Par...           NaN
# freq                                                    1           NaN
# mean                                                  NaN  7.049048e+05
# std                                                   NaN  4.444198e+05
# min                                                   NaN  1.500000e+05
# 25%                                                   NaN  3.240000e+05
# 50%                                                   NaN  6.120940e+05
# 75%                                                   NaN  8.925000e+05
# max                                                   NaN  2.099000e+06
#
#               beds       baths        sqft view_yn     yr_built cooling_yn  \
# count   151.000000  151.000000  151.000000     151   151.000000        151
# unique         NaN         NaN         NaN       2          NaN          2
# top            NaN         NaN         NaN     Yes          NaN        Yes
# freq           NaN         NaN         NaN      83          NaN         94
# mean      2.973510    2.238411   42.315296     NaN  1979.894040        NaN
# std       1.070495    0.754618   10.781706     NaN    15.440705        NaN
# min       1.000000    1.000000   24.494897     NaN  1941.000000        NaN
# 25%       2.000000    2.000000   33.984574     NaN  1970.000000        NaN
# 50%       3.000000    2.000000   40.236799     NaN  1979.000000        NaN
# 75%       4.000000    2.500000   49.295021     NaN  1988.000000        NaN
# max       6.000000    4.500000   67.609171     NaN  2023.000000        NaN
#
#        has_hoa senior_community_yn                      style  \
# count      151                 151                        151
# unique       2                   2                          2
# top        Yes                  No  Single Family Residential
# freq        89                 149                         95
# mean       NaN                 NaN                        NaN
# std        NaN                 NaN                        NaN
# min        NaN                 NaN                        NaN
# 25%        NaN                 NaN                        NaN
# 50%        NaN                 NaN                        NaN
# 75%        NaN                 NaN                        NaN
# max        NaN                 NaN                        NaN
#
#                   county new_construction_yn   log_price
# count                151                 151  151.000000
# unique                 2                   2         NaN
# top     Clackamas County                  No         NaN
# freq                 112                 149         NaN
# mean                 NaN                 NaN   13.274740
# std                  NaN                 NaN    0.629456
# min                  NaN                 NaN   11.918391
# 25%                  NaN                 NaN   12.688456
# 50%                  NaN                 NaN   13.324641
# 75%                  NaN                 NaN   13.701746
# max                  NaN                 NaN   14.556972

# %% [markdown]
# ## Checking OLS Assumptions

# %%
f, [[ax1, ax2], [ax3, ax4]] = plt.subplots(2, 2, sharey=True, figsize=(10, 10))
ax1.scatter(df['beds'], df['log_price'])
ax1.set_title('log_price and beds')
ax2.scatter(df['baths'], df['log_price'])
ax2.set_title('log_price and baths')
ax3.scatter(df['sqft'], df['log_price'])
ax3.set_title('log_price and sqft')
ax4.scatter(df['yr_built'], df['log_price'])
ax4.set_title('log_price and yr_built')

plt.show()

# %% [markdown]
# ## Create Dummy variables

# %%
# Reorder columns
columns = ['Address', 'link', 'price', 'log_price', 'beds', 'baths', 'sqft', 'yr_built', 'view_yn', 'cooling_yn', 'senior_community_yn', 'style', 'county', 'new_construction_yn', 'has_hoa']
df = df[columns]
cleaned_df = df[columns]

# %%
df = pd.get_dummies(df, columns=df.columns[8:], drop_first=True)

# %%
df.head()
# Out:
#                  Address                                               link  \
# 0  4965 SW Park Bluff Pl  https://www.redfin.com/OR/Lake-Oswego/4965-Par...
# 1        3569 Sunwood Ct  https://www.redfin.com/OR/Lake-Oswego/3569-Sun...
# 2     6338 Washington Ct  https://www.redfin.com/OR/Lake-Oswego/6338-Was...
# 3       4672 Winthrop Ct  https://www.redfin.com/OR/Lake-Oswego/4672-Win...
# 4       16900 Gassner Ln  https://www.redfin.com/OR/Lake-Oswego/16900-Ga...
#
#      price  log_price  beds  baths       sqft  yr_built  view_yn_Yes  \
# 0  2099000  14.556972     5    4.5  67.586981      2022            1
# 1   700000  13.458836     3    1.5  36.742346      1966            0
# 2   800000  13.592367     2    1.5  39.849718      1958            1
# 3  1790000  14.397726     5    3.5  64.505814      2020            0
# 4  1622500  14.299479     4    3.5  62.872888      1973            0
#
#    cooling_yn_Yes  senior_community_yn_Yes  style_Single Family Residential  \
# 0               1                        0                                1
# 1               0                        0                                1
# 2               1                        0                                1
# 3               1                        0                                1
# 4               1                        0                                1
#
#    county_Multnomah County  new_construction_yn_Yes  has_hoa_Yes
# 0                        0                        1            1
# 1                        0                        0            0
# 2                        0                        0            0
# 3                        0                        0            1
# 4                        0                        0            0

# %% [markdown]
# ## Checking for multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables = df[[ 'sqft', 'beds', 'yr_built', 'cooling_yn_Yes', 'style_Single Family Residential', 'county_Multnomah County', 'has_hoa_Yes']]
vif = pd.DataFrame()
vif['VIF'] = [variance_inflation_factor(variables.values, i) for i in range(variables.shape[1])]
vif["features"] = variables.columns

# %%
vif
# Out:
#          VIF                         features
# 0  54.771701                             sqft
# 1  34.704255                             beds
# 2  21.516566                         yr_built
# 3   3.535037                   cooling_yn_Yes
# 4   7.070522  style_Single Family Residential
# 5   1.695224          county_Multnomah County
# 6   3.376587                      has_hoa_Yes

# %% [markdown]
# ## Linear Regression Model

# %%
targets = df['price']
inputs = df.drop(['Address', 'link', 'price', 'baths', 'log_price', 'senior_community_yn_Yes', 'new_construction_yn_Yes', 'view_yn_Yes'], axis=1)

# %% [markdown]
# ### Scale the data

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(inputs)
# Out:
# StandardScaler()

# %%
inputs_scaled = scaler.transform(inputs)

# %%
inputs_scaled
# Out:
# array([[ 1.89933925,  2.3517414 ,  2.73602021, ...,  0.7677719 ,
#         -0.59009684,  0.83464317],
#        [ 0.02482796, -0.51860951, -0.90282642, ...,  0.7677719 ,
#         -0.59009684, -1.1981168 ],
#        [-0.91242768, -0.22944263, -1.42266166, ...,  0.7677719 ,
#         -0.59009684, -1.1981168 ],
#        ...,
#        [-0.91242768, -0.70075187, -0.05809417, ...,  0.7677719 ,
#         -0.59009684,  0.83464317],
#        [ 0.02482796,  1.04582844, -0.44797059, ...,  0.7677719 ,
#         -0.59009684,  0.83464317],
#        [ 0.02482796,  0.08530072, -1.74755868, ...,  0.7677719 ,
#         -0.59009684,  0.83464317]])

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(inputs_scaled, targets, test_size=0.2, random_state=0)

# %% [markdown]
# ### Ridge Regression

# %%
from sklearn.linear_model import Ridge
ridge = Ridge(alpha=5.0)
ridge.fit(x_train, y_train)
# Out:
# Ridge(alpha=5.0)

# %%
y_hat = ridge.predict(x_train)
plt.scatter(y_train, y_hat)
plt.show()

# %%
sns.displot(y_train - y_hat)
plt.title("Residuals PDF")
# Out:
# Text(0.5, 1.0, 'Residuals PDF')

# %%
ridge.score(x_train, y_train)
# Out:
# 0.8483630829823748

# %%
ridge.score(x_test, y_test)
# Out:
# 0.8865521776358535

# %%
def adj_r2(x,y):
    r2 = ridge.score(x,y)
    n = x.shape[0]
    p = x.shape[1]
    adjusted_r2 = 1-(1-r2)*(n-1)/(n-p-1)
    return adjusted_r2

# %%
adj_r2(x_train, y_train)
# Out:
# 0.8388857756687733

# %%
adj_r2(x_test, y_test)
# Out:
# 0.8520245795250263

# %%
reg_summary = pd.DataFrame(inputs.columns.values, columns=['Features'])
reg_summary['Weights'] = (np.exp(ridge.coef_ / scaler.scale_) - 1) * 100
# Out:
# /var/folders/74/tv0bg0gs343683qx5gss88h00000gn/T/ipykernel_43241/4212541744.py:2: RuntimeWarning: overflow encountered in exp
#   reg_summary['Weights'] = (np.exp(ridge.coef_ / scaler.scale_) - 1) * 100

# %%
from sklearn.feature_selection import f_regression
f_stat, p_values = f_regression(x_train, y_train)

# %%
reg_summary['f_stat'] = f_stat.round(3)
reg_summary['p_value'] = p_values.round(3)
reg_summary
# Out:
#                           Features  Weights   f_stat  p_value
# 0                             beds      inf  188.964    0.000
# 1                             sqft      inf  448.573    0.000
# 2                         yr_built      inf   21.222    0.000
# 3                   cooling_yn_Yes      inf   20.049    0.000
# 4  style_Single Family Residential      inf  103.347    0.000
# 5          county_Multnomah County   -100.0   12.383    0.001
# 6                      has_hoa_Yes   -100.0    7.826    0.006

# %%
y_hat_test = ridge.predict(x_test)

# %% [markdown]
# ## Test Dataset Error Plot

# %%
plt.scatter(y_test, y_hat_test)
plt.show()

# %%
df_pf = pd.DataFrame(y_hat_test, columns=['predictions'])

# %%
y_test = y_test.reset_index(drop=True)
df_pf['target'] = y_test
df_pf
# Out:
#     predictions   target
# 0     940850.81   900000
# 1    1688115.77  1745000
# 2     242581.47   244900
# 3     348486.51   330000
# 4    1098403.03  1109000
# 5     814650.90   785000
# 6     815005.34   810000
# 7     894986.71   924229
# 8     618233.32   612000
# 9     349153.13   321000
# 10    575323.80   612094
# 11   1919602.08  2000000
# 12    638983.33   635689
# 13    260409.35   265000
# 14    678002.54   680000
# 15    169380.79   225000
# 16    312342.54   292122
# 17   1406413.71  1425000
# 18    720976.10   715000
# 19    452128.39   391610
# 20    602477.18   610000
# 21    326676.25   340000
# 22   1537266.23  1575000
# 23    263710.11   261249
# 24    814099.18   824900
# 25    622040.52   612720
# 26    381794.79   360000
# 27    811083.96   785000
# 28    614966.69   595000
# 29   1769610.87  1850000
# 30    592331.64   550000

# %%
df_pf['residual'] = df_pf['target'] - df_pf['predictions']
df_pf['Difference%'] = (df_pf['residual']/df_pf['target']*100).round(2)
df_pf
# Out:
#     predictions   target  residual  Difference%
# 0     940850.81   900000 -40850.81        -4.54
# 1    1688115.77  1745000  56884.23         3.26
# 2     242581.47   244900   2318.53         0.95
# 3     348486.51   330000 -18486.51        -5.60
# 4    1098403.03  1109000  10596.97         0.96
# 5     814650.90   785000 -29650.90        -3.78
# 6     815005.34   810000  -5005.34        -0.62
# 7     894986.71   924229  29242.29         3.16
# 8     618233.32   612000  -6233.32        -1.02
# 9     349153.13   321000 -28153.13        -8.77
# 10    575323.80   612094  36770.20         6.01
# 11   1919602.08  2000000  80397.92         4.02
# 12    638983.33   635689  -3294.33        -0.52
# 13    260409.35   265000   4590.65         1.73
# 14    678002.54   680000   1997.46         0.29
# 15    169380.79   225000  55619.21        24.72
# 16    312342.54   292122 -20220.54        -6.92
# 17   1406413.71  1425000  18586.29         1.30
# 18    720976.10   715000  -5976.10        -0.84
# 19    452128.39   391610 -60518.39       -15.45
# 20    602477.18   610000   7522.82         1.23
# 21    326676.25   340000  13323.75         3.92
# 22   1537266.23  1575000  37733.77         2.40
# 23    263710.11   261249  -2461.11        -0.94
# 24    814099.18   824900  10800.82         1.31
# 25    622040.52   612720  -9320.52        -1.52
# 26    381794.79   360000 -21794.79        -6.05
# 27    811083.96   785000 -26083.96        -3.32
# 28    614966.69   595000 -19966.69        -3.36
# 29   1769610.87  1850000  80389.13         4.35
# 30    592331.64   550000 -42331.64        -7.70

# %%
import scipy.stats as stats
SE_residual = np.sqrt(np.sum(df_pf['residual']**2) / (len(y_test) - x_test.shape[1]))
margin_error = SE_residual*stats.t.ppf(.9, len(x_test) - 1)
df_pf['lower_bound'] = df_pf['predictions'] - margin_error
df_pf['upper_bound'] = df_pf['predictions'] + margin_error
df_pf
# Out:
#     predictions   target  residual  Difference%  lower_bound  upper_bound
# 0     940850.81   900000 -40850.81        -4.54    889711.33    991990.28
# 1    1688115.77  1745000  56884.23         3.26   1636976.30   1739255.25
# 2     242581.47   244900   2318.53         0.95    191441.99    293720.94
# 3     348486.51   330000 -18486.51        -5.60    297347.03    399625.99
# 4    1098403.03  1109000  10596.97         0.96   1047263.55   1149542.51
# 5     814650.90   785000 -29650.90        -3.78    763511.42    865790.38
# 6     815005.34   810000  -5005.34        -0.62    763865.86    866144.81
# 7     894986.71   924229  29242.29         3.16    843847.23    946126.19
# 8     618233.32   612000  -6233.32        -1.02    567093.84    669372.80
# 9     349153.13   321000 -28153.13        -8.77    298013.66    400292.61
# 10    575323.80   612094  36770.20         6.01    524184.32    626463.27
# 11   1919602.08  2000000  80397.92         4.02   1868462.60   1970741.55
# 12    638983.33   635689  -3294.33        -0.52    587843.85    690122.81
# 13    260409.35   265000   4590.65         1.73    209269.88    311548.83
# 14    678002.54   680000   1997.46         0.29    626863.07    729142.02
# 15    169380.79   225000  55619.21        24.72    118241.31    220520.27
# 16    312342.54   292122 -20220.54        -6.92    261203.07    363482.02
# 17   1406413.71  1425000  18586.29         1.30   1355274.24   1457553.19
# 18    720976.10   715000  -5976.10        -0.84    669836.62    772115.57
# 19    452128.39   391610 -60518.39       -15.45    400988.91    503267.86
# 20    602477.18   610000   7522.82         1.23    551337.70    653616.66
# 21    326676.25   340000  13323.75         3.92    275536.77    377815.73
# 22   1537266.23  1575000  37733.77         2.40   1486126.75   1588405.70
# 23    263710.11   261249  -2461.11        -0.94    212570.63    314849.58
# 24    814099.18   824900  10800.82         1.31    762959.70    865238.66
# 25    622040.52   612720  -9320.52        -1.52    570901.04    673179.99
# 26    381794.79   360000 -21794.79        -6.05    330655.31    432934.27
# 27    811083.96   785000 -26083.96        -3.32    759944.49    862223.44
# 28    614966.69   595000 -19966.69        -3.36    563827.22    666106.17
# 29   1769610.87  1850000  80389.13         4.35   1718471.39   1820750.35
# 30    592331.64   550000 -42331.64        -7.70    541192.17    643471.12

# %% [markdown]
# # Writing predictions to csv

# %%
predicted_price = ridge.predict(inputs_scaled)
cleaned_df['predicted_price'] = predicted_price
pd.set_option('display.float_format', lambda x: '%.2f' % x)
cleaned_df['difference'] = cleaned_df['predicted_price'] - cleaned_df['price']
cleaned_df['difference%'] = 100*cleaned_df['difference']/cleaned_df['price']
column_order = ['Address', 'link', 'price', 'predicted_price', 'difference', 'difference%', 'beds', 'baths', 'sqft',
       'yr_built', 'view_yn', 'cooling_yn', 'senior_community_yn', 'style',
       'county', 'new_construction_yn', 'has_hoa']
cleaned_df = cleaned_df[column_order]
cleaned_df
# Out:
#                    Address                                               link  \
# 0    4965 SW Park Bluff Pl  https://www.redfin.com/OR/Lake-Oswego/4965-Par...
# 1          3569 Sunwood Ct  https://www.redfin.com/OR/Lake-Oswego/3569-Sun...
# 2       6338 Washington Ct  https://www.redfin.com/OR/Lake-Oswego/6338-Was...
# 3         4672 Winthrop Ct  https://www.redfin.com/OR/Lake-Oswego/4672-Win...
# 4         16900 Gassner Ln  https://www.redfin.com/OR/Lake-Oswego/16900-Ga...
# ..                     ...                                                ...
# 146      5254 Westfield Ct  https://www.redfin.com/OR/Lake-Oswego/5254-Wes...
# 147          4638 Lower Dr  https://www.redfin.com/OR/Lake-Oswego/4638-Low...
# 148      4324 Woodside Cir  https://www.redfin.com/OR/Lake-Oswego/4324-Woo...
# 149      110 Greenridge Ct  https://www.redfin.com/OR/Lake-Oswego/110-Gree...
# 150        4487 Westbay Rd  https://www.redfin.com/OR/Lake-Oswego/4487-Wes...
#
#        price  predicted_price  difference  difference%  beds  baths  sqft  \
# 0    2099000       1996007.96  -102992.04        -4.91     5   4.50 67.59
# 1     700000        680456.78   -19543.22        -2.79     3   1.50 36.74
# 2     800000        770527.53   -29472.47        -3.68     2   1.50 39.85
# 3    1790000       1733537.17   -56462.83        -3.15     5   3.50 64.51
# 4    1622500       1567126.07   -55373.93        -3.41     4   3.50 62.87
# ..       ...              ...         ...          ...   ...    ...   ...
# 146  1300000       1276651.07   -23348.93        -1.80     4   2.50 57.84
# 147   307500        319034.21    11534.21         3.75     2   1.50 35.50
# 148   579000        565456.19   -13543.81        -2.34     2   2.00 34.79
# 149   527000        611630.26    84630.26        16.06     3   2.50 53.55
# 150  1200000       1087012.89  -112987.11        -9.42     3   2.00 43.23
#
#      yr_built view_yn cooling_yn senior_community_yn  \
# 0        2022     Yes        Yes                  No
# 1        1966      No         No                  No
# 2        1958     Yes        Yes                  No
# 3        2020      No        Yes                  No
# 4        1973      No        Yes                  No
# ..        ...     ...        ...                 ...
# 146      1988     Yes        Yes                  No
# 147      1975      No         No                  No
# 148      1979     Yes        Yes                  No
# 149      1973      No         No                  No
# 150      1953     Yes        Yes                  No
#
#                          style            county new_construction_yn has_hoa
# 0    Single Family Residential  Clackamas County                 Yes     Yes
# 1    Single Family Residential  Clackamas County                  No      No
# 2    Single Family Residential  Clackamas County                  No      No
# 3    Single Family Residential  Clackamas County                  No     Yes
# 4    Single Family Residential  Clackamas County                  No      No
# ..                         ...               ...                 ...     ...
# 146  Single Family Residential  Clackamas County                  No     Yes
# 147                Condo/Co-op  Clackamas County                  No     Yes
# 148  Single Family Residential  Clackamas County                  No     Yes
# 149  Single Family Residential  Clackamas County                  No     Yes
# 150  Single Family Residential  Clackamas County                  No     Yes
#
# [151 rows x 17 columns]

# %%
cleaned_df.to_csv('predictions/nonlog_ridge_predictions.csv')
